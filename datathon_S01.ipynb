# %%
import os
import re
import zipfile
import ast
import json
import pandas as pd
from datetime import datetime, timedelta

import torch
from torch.utils.data import DataLoader, TensorDataset
import torch.nn as nn
import torch.optim as optim
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from transformers import pipeline
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 9
#       6 import pandas as pd
#       7 from datetime import datetime, timedelta
# ----> 9 import torch
#      10 from torch.utils.data import DataLoader, TensorDataset
#      11 import torch.nn as nn
#
# ModuleNotFoundError: No module named 'torch'

# %% [markdown]
# ### Loading data

# %%
#passport csv file

passport_pd = pd.read_csv('./passport_data_with_label.csv')

passport_pd.head(5)
# Out:
#          index first_name middle_name    last_name gender      country  \
# 0     client_0      Freja     Katrine  Christensen      F      Denmark
# 1     client_1     Thomas     Laurent     Lemaître      M       France
# 2    client_10   Gauthier         NaN      Bernard      M       France
# 3   client_100      Louna         Ève     Bertrand      F       France
# 4  client_1000      Britt     Daantje     Van Dijk      F  Netherlands
#
#   country_code nationality  birth_date passport_number  \
# 0          DNK      Danish  2002-04-18       UE2130779
# 1          FRA      French  1990-02-07       OT9354543
# 2          FRA      French  1974-05-31       XV2857876
# 3          FRA      French  1977-12-25       KI8826467
# 4          NLD       Dutch  1982-03-13       XA0813292
#
#                                         passport_mrz passport_issue_date  \
# 0  ['P<DNKCHRISTENSEN<<FREJA<KATRINE<<<<<<<<<<<<<...          2017-05-11
# 1  ['P<FRALEMAÎTRE<<THOMAS<LAURENT<<<<<<<<<<<<<<<...          2022-06-28
# 2  ['P<FRABERNARD<<GAUTHIER<<<<<<<<<<<<<<<<<<<<<<...          2023-03-18
# 3  ['P<FRABERTRAND<<LOUNA<ÈVE<<<<<<<<<<<<<<<<<<<<...          2019-11-11
# 4  ['P<NLDVAN DIJK<<BRITT<DAANTJE<<<<<<<<<<<<<<<<...          2021-10-01
#
#   passport_expiry_date   label
# 0           2027-05-10  Accept
# 1           2032-06-27  Reject
# 2           2033-03-17  Accept
# 3           2029-11-10  Accept
# 4           2031-09-30  Reject

# %%
account_form_pd = pd.read_csv('./account_form_data_with_label.csv')

account_form_pd.head(20)
# Out:
#           index                           name first_name middle_name  \
# 0      client_0      Freja Katrine Christensen      Freja     Katrine
# 1      client_1        Thomas Laurent Lemaître     Thomas     Laurent
# 2     client_10               Gauthier Bernard   Gauthier         NaN
# 3    client_100             Louna Ève Bertrand      Louna         Ève
# 4   client_1000         Britt Daantje Van Dijk      Britt     Daantje
# 5   client_1001       Francesca Ilaria Ferrari  Francesca      Ilaria
# 6   client_1002                 Consuelo Ramos   Consuelo         NaN
# 7   client_1003              Sofía Dácil Ramos      Sofía       Dácil
# 8   client_1004         Schmidt Schwarz Binder    Schmidt     Schwarz
# 9   client_1005   Gruber Schwarz Hinterleitner     Gruber     Schwarz
# 10  client_1006       Gabriella Amélie Sanders  Gabriella      Amélie
# 11  client_1007     Jørgensen Olsen Nørregaard  Jørgensen       Olsen
# 12  client_1008          Lina Fabienne Richter       Lina    Fabienne
# 13  client_1009            Uhlig Klein Fischer      Uhlig       Klein
# 14   client_101         Vázquez Álvarez Ortega    Vázquez     Álvarez
# 15  client_1010         Richter Fischer Krüger   Rgichter     Fischer
# 16  client_1011  Piirainen Savolainen Mustonen  Piirainen  Savolainen
# 17  client_1012       Roelandts Lemaire Peiren  Roelandts     Lemaire
# 18  client_1013                Isabella Fabbri   Isabella         NaN
# 19  client_1014            Emma Margaux Bonnet       Emma     Margaux
#
#         last_name passport_number currency country_of_domicile  \
# 0     Christensen       UE2130779      DKK             Denmark
# 1           Louis       OT9354543      EUR              France
# 2         Bernard       XV2857876      EUR              France
# 3        Bertrand       KI8826467      EUR              France
# 4        Van Dijk       XA0813292      EUR         Netherlands
# 5         Ferrari       MD8743029      EUR               Italy
# 6           Ramos       ZS0877519      EUR               Spain
# 7           Ramos       YR1788551      EUR             Finland
# 8          Binder       HK7376680      EUR             Austria
# 9   Hinterleitner       ZX0148401      EUR             Austria
# 10        Sanders       BZ8139434      EUR             Belgium
# 11     Nørregaard       KG3997293      DKK             Denmark
# 12        Richter       TN3991557      EUR             Germany
# 13        Fischer       NV4744409      EUR             Germany
# 14         Ortega       QV5663364      EUR               Spain
# 15         rKüger       FM0339491      EUR             Germany
# 16       Mustonen       AR1555887      EUR             Finland
# 17         Peiren       JC9209829      EUR             Belgium
# 18         Fabbri       ZT8922149      DKK             Denmark
# 19         Bonnet       NM5921571      EUR              France
#
#           phone_number                    email_address address.city  \
# 0          53 11 20 42      freja.christensen@yousee.dk      Aalborg
# 1   ++4903 52 25 79 49        thomas.lemaitre@yahoo.com     Le Havre
# 2       06 85 81 21 11  gauthier.bernard@numericable.fr        Reims
# 3   +33 04 18 03 86 04       louna.bertrand@hotmail.com  Montpellier
# 4      +31 06 92689079          britt.vandijk@yahoo.com    Eindhoven
# 5      +39 342 8847590         francesca.ferrari@tin.it        Siena
# 6          680 909 777          consuelo.ramos@terra.es    Salamanca
# 7        047 901 94 31            sofia.ramos@yahoo.com      Mikkeli
# 8     +43 754 060 7626       schmidt.binder@outlook.com   Eisenstadt
# 9     +43 615 790 1978  gruber.hinterleitner@icloud.com   Klagenfurt
# 10    +32 0487 455 891     gabriella.sanders@icloud.com     Turnhout
# 11     +45 71 09 44 96  jrgensen.nrregaard@cybercity.dk      Esbjerg
# 12     +49 5111 689575         lina.richter@vodafone.de       Berlin
# 13     +49 4008 397798        uhlig.fischer@vodafone.de      Dresden
# 14         689 330 477         vazquez.ortega@gmail.com         Vigo
# 15     +49 8831 489987       richter.kruger@outlook.com        Fürth
# 16  +358 044 454 06 55   piirainen.mustonen@outlook.com     Helsinki
# 17    +32 0407 358 025     roelandts.peiren@belgacom.be     Kortrijk
# 18     +45 74 81 17 52      isabella.fabbri@hotmail.com      Næstved
# 19  +33 06 36 52 87 13          emma.bonnet@hotmail.com        Tours
#
#         address.street_name  address.street_number address.postal_code   label
# 0                   Strøget                   57.0                2044  Accept
# 1    Boulevard Saint-Michel                   88.0               63950  Reject
# 2        Rue de la Huchette                   36.0               70164  Accept
# 3         Rue de Strasbourg                   75.0               45774  Accept
# 4            Willemsparkweg                   80.0             1698 64  Reject
# 5           Piazza Maggiore                    7.0               14045  Reject
# 6                  Gran Vía                   39.0               77965  Accept
# 7            Puistolanaukio                   26.0               21913  Accept
# 8   Landstraßer Hauptstraße                   35.0                6293  Reject
# 9           Gasometerstraße                   35.0                3046  Reject
# 10          Rue de l'Église                   27.0                8893  Reject
# 11            Rådhuspladsen                   36.0                0976  Reject
# 12            Europa-Center                   59.0               54687  Reject
# 13              Weinstrasse                   65.0               79618  Accept
# 14  Calle de la Universidad                   62.0               49493  Reject
# 15      Großer Hirschgraben                   77.0               09543  Reject
# 16       Kauppakartanonkatu                   28.0               46628  Accept
# 17         Rue de la Vierge                   85.0                5886  Accept
# 18                Æbeløgade                   76.0                1011  Accept
# 19          Rue de la Santé                   21.0               29739  Accept

# %%
description_pd = pd.read_csv('./client_profile_data_with_label.csv')
description_pd.head(5)
# Out:
#          index                       name country_of_domicile  birth_date  \
# 0     client_0  Freja Katrine Christensen             Denmark  2002-04-18
# 1     client_1    Thomas Laurent Lemaître              France  1990-02-07
# 2    client_10           Gauthier Bernard              France  1974-05-31
# 3   client_100         Louna Ève Bertrand              France  1977-12-25
# 4  client_1000     Britt Daantje Van Dijk         Netherlands  1982-03-13
#
#   nationality passport_number passport_issue_date passport_expiry_date gender  \
# 0      Danish       UE2130779          2017-05-11           2027-05-10      F
# 1      French       OT9354543          2022-06-28           2032-06-27      M
# 2      French       XV2857876          2023-03-18           2033-03-17      M
# 3      French       KI8826467          2019-11-11           2029-11-10      F
# 4       Dutch       XA0813292          2021-10-01           2031-09-30      F
#
#          phone_number  ... address.postal_code          secondary_school.name  \
# 0         53 11 20 42  ...                2044            Holstebro Gymnasium
# 1      03 52 25 79 49  ...               63950    Lycée International de Lyon
# 2      06 85 81 21 11  ...               70164           Lycée Gustave Eiffel
# 3  +33 04 18 03 86 04  ...               45774                  Lycée Chaptal
# 4     +31 06 92689079  ...             1698 64  Oosterlicht College Groningen
#
#   secondary_school.graduation_year aum.savings aum.inheritance  \
# 0                             2022           0        13140000
# 1                             2009       80000         2300000
# 2                             1992      360000         1360000
# 3                             1996      350000         2240000
# 4                             1999      210000          930000
#
#   aum.real_estate_value inheritance_details.relationship  \
# 0                     0                      grandmother
# 1               4690000                      grandmother
# 2               3200000                           father
# 3               6070000                           mother
# 4               3610000                      grandmother
#
#   inheritance_details.inheritance_year inheritance_details.profession   label
# 0                               2020.0          Oil and Gas Executive  Accept
# 1                               2016.0          Real Estate Developer  Reject
# 2                               2006.0          Real Estate Developer  Accept
# 3                               2014.0              Tech Entrepreneur  Accept
# 4                               2009.0              Tech Entrepreneur  Reject
#
# [5 rows x 34 columns]

# %%
client_profile_pd = pd.read_csv('./client_profile_data_with_label.csv')
client_profile_pd.head(5)
# Out:
# {'Summary Note': 'Rossi Conti Fabbri and the RM met at a financial seminar in Rome. They attended several workshops together and exchanged ideas on market trends, which sparked a long-term professional relationship.\nRossi Conti Fabbri is a 68 year old and comes from Italy.\nAfter extensive research, he chose Julius Baer for its strong track record in managing high-net-worth clients.\n', 'Family Background': 'Rossi Conti Fabbri is currently divorced. He does not have any children.', 'Education Background': 'Rossi completed his secondary education at Scuola Superiore di Lingue e Letterature Straniere per Interpreti e Traduttori Milano in 1974.\nRossi graduated from Luiss Guido Carli in 1979, completing his higher education.\n', 'Occupation History': 'With a career spanning nearly 45 years, Rossi Conti Fabbri has established himself as a key player in the industry.\nAt Banca Monte dei Paschi di Siena S.p.A., Rossi Conti Fabbri held the position of Family Office Manager from 1980 to 1981, developing essential skills in the field.\nAfter gaining experience, he took on the role of Investment Director at UniCredit S.p.A. in 1982, further expanding his skill set.\nHe spent 1 years working as a CFO at UniCredit S.p.A., refining his expertise and building a strong network.\nIn 1987, he transitioned to UniCredit S.p.A. to take on the position of COO, capitalizing on his expertise to propel business growth.\nBefore retiring, Rossi Conti Fabbri worked as a CEO at Banca Monte dei Paschi di Siena S.p.A. from 1994 to 2017.', 'Wealth Summary': 'He managed to save approximately 1540000 EUR from his earnings at all companies.\nHe has condo located in Padua, worth 730000 EUR.\n\nIn addition to his primary residence, he owns villa in Brescia worth 1986000 EUR.\n\nOn top of that he inherited a beautiful condo in Milan, which could be used as a weekend getaway. It is valued at 1000000 EUR.\nHe does not have any inheritances.', 'Client Summary': 'The RM knows the client very well and is a good friend of the entire family.\n'}

# %% [markdown]
# ### Filtering Rules

# %%
def check_mrz(data):
    birth_date = str(data["birth_date"])  # Convert birth_date to string
    # print(birth_date)
    mrz_date = birth_date[2:4] + birth_date[5:7] + birth_date[8:10]

    middle_name = str(data["middle_name"])  # Convert middle_name to string
    if middle_name == '' or middle_name == 'nan' or middle_name == 'None':
        passport_mrz_temp_1 = "P<"+str(data["country_code"])+str(data["last_name"])+"<<"+str(data["first_name"])  # Convert other fields to string
    else:
        passport_mrz_temp_1 = "P<"+str(data["country_code"])+str(data["last_name"])+"<<"+str(data["first_name"])+"<"+middle_name

    passport_mrz_temp_2 = str(data["passport_number"])+str(data["country_code"])+ mrz_date  # Convert other fields to string
    #mrz_arr = ast.literal_eval(data["passport_mrz"])
    mrz_arr = eval(data["passport_mrz"])
    #print(mrz_arr[0], mrz_arr[1])


    passport_mrz_1 = mrz_arr[0].lower().rstrip('<')
    passport_mrz_2 = mrz_arr[1].lower().rstrip('<')


    if passport_mrz_1 != passport_mrz_temp_1.lower() or passport_mrz_2 != passport_mrz_temp_2.lower() :

        return True

    return False

# %%
def check_name(account_per, profile_per, passport_per):
    # Conditionally include middle name
    passport_name = str(passport_per["first_name"])
    if not pd.isnull(passport_per["middle_name"]) and passport_per["middle_name"] != "":  # Check for null or empty middle name
        passport_name += str(passport_per["middle_name"])
    passport_name += str(passport_per["last_name"])
    passport_name = passport_name.replace(" ", "")

    account_name_1 = account_per["name"].replace(" ", "")

    account_name_2 = str(passport_per["first_name"])
    if not pd.isnull(passport_per["middle_name"]) and passport_per["middle_name"] != "":  # Check for null or empty middle name
        account_name_2 += str(passport_per["middle_name"])
    account_name_2 += str(passport_per["last_name"])
    account_name_2 = account_name_2.replace(" ", "")

    profile_name = profile_per["name"].replace(" ", "")

    names = [passport_name, account_name_1, account_name_2, profile_name]

    if len(set(names)) != 1:
        return True
    return False

# %%
def check_phonenumber(account_per, profile_per):
    phone_number = account_per["phone_number"]
    if pd.isnull(phone_number) or phone_number == "":
        return True
    if phone_number.startswith('++'):
        return True
    if phone_number != profile_per["phone_number"]:
        return True
    return False

# %%
def check_address(account_per, profile_per):
    postal_code = account_per["address.postal_code"]
    if pd.isnull(postal_code) or postal_code == "" or account_per["address.street_number"] != profile_per["address.street_number"] or account_per["address.city"] != profile_per["address.city"] or account_per["address.street_name"] != profile_per["address.street_name"]:
        return True

    return False

# %%
def check_passport_dates(df):
    # Corrected the function to handle the case where it receives a single row as input.
    if isinstance(df, pd.Series):
        df = df.to_frame().T  # Convert the Series into a DataFrame
    # print(df['passport_issue_date'])
    # Convert date columns to datetime objects if they aren't already
    df['passport_issue_date'] = pd.to_datetime(df['passport_issue_date'], errors='coerce')
    df['passport_expiry_date'] = pd.to_datetime(df['passport_expiry_date'], errors='coerce')
    # Get today's date and calculate 10 years ago
    today = datetime.today()
    ten_years_ago = today - timedelta(days=10*365)
    # Check for invalid dates (NaT - Not a Time)
    invalid_issue_date = df['passport_issue_date'].isnull()
    invalid_expiry_date = df['passport_expiry_date'].isnull()
    # print(invalid_issue_date, "dd", invalid_expiry_date)
    # Check for invalid date order (expiry date should be after issue date)
    invalid_date_order = df['passport_expiry_date'] < df['passport_issue_date']
    # Check if expiry date is older than 10 years
    expiry_date_older_than_10_years = df['passport_expiry_date'] < ten_years_ago
    # Duration between issue and expiry dates
    duration = df['passport_expiry_date'] - df['passport_issue_date']
    # Check if duration is less than 731 days
    duration_less_than_730_days = duration < pd.Timedelta(days=731)
    # Check if duration is more than 3652 days
    duration_more_than_3652_days = duration > pd.Timedelta(days=3652)
    # Check birth before issue date
    birth_date = pd.to_datetime(df['birth_date'], errors='coerce')
    birth_before_issue_date = df['passport_issue_date'] < birth_date
    if any(invalid_issue_date | invalid_expiry_date | invalid_date_order | expiry_date_older_than_10_years | duration_less_than_730_days | duration_more_than_3652_days | birth_before_issue_date):
        return True
    return False

# %%
def check_email(account_per, profile_per):
    if account_per["email_address"] != profile_per["email_address"]:
        return True
    return False

# %%
def check_nationality(passport_per, account_per, profile_per):
    if passport_per["nationality"] != profile_per["nationality"]:
        return True
    return False

check_email(account_form_pd.iloc[1], client_profile_pd.iloc[1])

# %%
def check_country_of_domicile(account_per, profile_per):
    if account_per["country_of_domicile"] != profile_per["country_of_domicile"]:
        return True
    return False

# check_country_of_domicile(account_form_pd.iloc[5], client_profile_pd.iloc[1])

# %%
def check_birthdate(passport_per, profile_per):
    if passport_per["birth_date"] != profile_per["birth_date"]:
        return True
    return False

# %%
def check_currency(account_per, profile_per):
    valid_currencies = ['CHF','DKK','EUR']
    if account_per["currency"] not in valid_currencies or profile_per["currency"] not in valid_currencies:
        return True
    if account_per["currency"] != profile_per["currency"]:
        return True
    return False

# %%
def check_gender(passport_per, profile_per):
    if passport_per["gender"] != profile_per["gender"]:
        return True
    return False

# %%
def check_real_estate_value(profile_per):
    aum_value = profile_per["aum.real_estate_value"]
    real_estate_details = profile_per["real_estate_details"]

    # Handle missing values
    if pd.isnull(aum_value) or pd.isnull(real_estate_details):
        return True  # Invalid if either value is missing

    try:
        property_values = [prop["property value"] for prop in eval(real_estate_details)]
        total_real_estate_value = sum(property_values)

        # Check if total real estate value is not equal to the aum_value
        if total_real_estate_value != aum_value:
            return True  # Invalid if real estate value is greater

    except (TypeError, KeyError, ValueError):
        return True  # Invalid if data is not in the expected format

    return False

# %%
def check_passport(passport_per, account_per, profile_per):
    if passport_per["passport_number"] != account_per["passport_number"] or passport_per["passport_number"] != profile_per["passport_number"]:
        return True
    if  passport_per["passport_issue_date"] != profile_per["passport_issue_date"]:
        return True
    if  passport_per["passport_expiry_date"] != profile_per["passport_expiry_date"]:
        return True
    return False

# %%
def check_multiple_countries(account_per, profile_per):
    # Check if there's more than one country of domicile
    account_mult = account_per["country_of_domicile"]
    profile_mult = profile_per["country_of_domicile"]

    if pd.isnull(account_mult) or pd.isnull(profile_mult):
        return True
    # Split the country strings into lists
    account_countries = [country.strip() for country in account_mult.split(",")]
    profile_countries = [country.strip() for country in profile_mult.split(",")]

    # Check if the lengths of the lists are greater than 1
    if len(account_countries) > 1 or len(profile_countries) > 1:
        return True  # Invalid if more than one country is found

    return False

# %%
# Postal code patterns for European countries
europe_postal_code_patterns = {
    'Austria': r'^\d{4}$',
    'Belgium': r'^\d{4}$',
    'Bulgaria': r'^\d{4}$',
    'Switzerland': r'^\d{4}$',
    'Czech Republic': r'^\d{3}\s?\d{2}$',
    'Germany': r'^\d{5}$',
    'Denmark': r'^\d{4}$',
    'Estonia': r'^\d{5}$',
    'Spain': r'^\d{5}$',
    'Finland': r'^\d{5}$',
    'France': r'^\d{5}$',
    'Greece': r'^\d{3}\s?\d{2}$',
    'Croatia': r'^\d{5}$',
    'Hungary': r'^\d{4}$',
    'Ireland': r'^[A-Za-z]\d[\w\d]? ?\d[A-Za-z]{2}$',
    'Italy': r'^\d{5}$',
    'Lithuania': r'^LT-\d{5}$|^\d{5}$',
    'Luxembourg': r'^\d{4}$',
    'Latvia': r'^LV-\d{4}$|^\d{4}$',
    'Malta': r'^[A-Z]{3}\s?\d{4}$',
    'Netherlands': r'^\d{6}$',
    'Norway': r'^\d{4}$',
    'Poland': r'^\d{2}-\d{3}$',
    'Portugal': r'^\d{4}-\d{3}$',
    'Romania': r'^\d{6}$',
    'Sweden': r'^\d{3}\s?\d{2}$',
    'Slovenia': r'^\d{4}$',
    'Slovakia': r'^\d{3}\s?\d{2}$',
    'United Kingdom': r'^[A-Z]{1,2}\d[A-Z\d]?\s?\d[A-Z]{2}$',
}

def check_europe_postal_code(account_per, profile_per):
    country = account_per["country_of_domicile"]
    postal_code = str(account_per["address.postal_code"]).replace(" ", "")
    country_pr = profile_per["country_of_domicile"]
    postal_code_pr = str(profile_per["address.postal_code"]).replace(" ", "")
    label_account = account_per["label"]
    if pd.isnull(country) or pd.isnull(postal_code) :
        return True
    pattern = europe_postal_code_patterns.get(country)
    if not pattern:
        print(f"No postal code format available for: {country}")
        return True
    if re.match(pattern, postal_code.strip()) is None :
        print(f"Invalid postal code for {country}: {postal_code}")
        return True

    if pd.isnull(country_pr) or pd.isnull(postal_code_pr) :
        return True
    pattern = europe_postal_code_patterns.get(country)
    if not pattern:
        print(f"No postal code format available for: {country_pr}")
        return True
    if re.match(pattern, postal_code_pr.strip()) is None :
        print(f"Invalid postal code for {country_pr}: {postal_code_pr}")
        return True
    # else:
    #     print(f"Invalid postal code for {country}: {postal_code}")
    return False

# %%
def get_description_info(data, model):
    Summary_Note = data["Summary Note"]
    Family_Background = data["Family Background"]
    Education_Background=data["Education Background"]
    Occupation_History = data["Occupation History"]
    Wealth_Summary = data["Wealth Summary"]
    Client_Summary = data["Client Summary"]
    kyc_text = f'''
        "Summary Note" : "{Summary_Note}",
        "Family Background": "{Family_Background}",
        "Education Backgroun": "{Education_Background}",
        "Occupation History": "{Occupation_History}",
        "Wealth Summary": "{Wealth_Summary}",
        "Client Summary": "{Client_Summary}",
       
    '''  

    prompt = f"""
    Extract the following information from the client description below:
    - Full name
    - Marital_status
    - Age
    - Nationality
    - Job title
    - Company
    - List of real estate assets (type, location, value)
    - Total savings

    Text: {kyc_text}
    """

    extracted = model(prompt, max_new_tokens=512)[0]["generated_text"]
    return extracted

def parse_kyc_info(text):
    pattern = r"-\s*(.*?)\s+is\s+(.*?)(?=-|$)"
    matches = re.findall(pattern, text)

    result = {}
    for key, value in matches:
        clean_key = key.strip().lower().replace(" ", "_")
        result[clean_key] = value.strip()

    if "list of real estate assets (type, location, value)" in text:
        result["real_estate_assets"] = None

    return result
def check_description(index, model):

    profile_per = client_profile_pd.loc[index]
    profile_name = profile_per["name"]
    profile_marital_status = profile_per["marital_status"]
    profile_nationality = profile_per["nationality"]
    profile_birth_date = profile_per["birth_date"]

    birth_date = datetime.strptime(profile_birth_date, "%Y-%m-%d")
    today = datetime.today()
    profile_age = today.year - birth_date.year - ((today.month, today.day) < (birth_date.month, birth_date.day))

    profile_savings =  profile_per["aum.savings"]
    profile_inheritance = profile_per["aum.inheritance"]
    profile_real_estate_value = profile_per["aum.real_estate_value"]
    profile_total = profile_savings+profile_inheritance+profile_real_estate_value
    
    description_per = description_pd.loc[index]
    info = get_description_info(description_per, model)
    info_dict = parse_kyc_info(info)

    full_name = info_dict["full_name"]
    marital_status = info_dict["fmarital_status"]
    nationality = info_dict["nationality"]
    age = info_dict["age"]
    total_savings = info_dict["list_of_real_estate_assets_(type,_location,_value)-_total_savings"]

    try:
        total_savings = float(total_savings)
        age = int(age)
    except (ValueError, TypeError):
        pass
    
    try:
        profile_savings = float(profile_savings)
        profile_inheritance = float(profile_inheritance)
        profile_real_estate_value = float(profile_real_estate_value)
        profile_total = float(profile_total)
    except (ValueError, TypeError):
        pass

    if full_name != profile_name:
        print(profile_name)
        print(full_name)
        return True
    if marital_status != profile_marital_status:
        print(marital_status)
        print(profile_marital_status)
        return True
    if nationality != profile_nationality:
        print(nationality)
        print(profile_nationality)
        return True
    if total_savings != profile_savings:
        print(total_savings)
        print(profile_savings)
        return True
    if age != profile_age:
        print(age)
        print(profile_age)
        return True

# %% [markdown]
# ### Filtering Data

# %%
def validate_data(passport_pd, account_form_pd, client_profile_pd,LLM_Model):
    rejected_ids = []
    labels = []

    for index in account_form_pd.index:
        passport_per = passport_pd.loc[index]
        account_per = account_form_pd.loc[index]
        profile_per = client_profile_pd.loc[index]

        is_rejected = False
        client_id = passport_per['index']
        label = passport_per['label']

        if check_passport(passport_per, account_per, profile_per):
            print("Sorry! You are being rejected because the passport number is wrong.", client_id)
            rejected_ids.append(client_id)
            labels.append(label)
            print(client_id, label)
            continue

        if check_name(account_per, profile_per, passport_per):
            print("Sorry! You are being rejected because the name is wrong.", client_id)
            rejected_ids.append(client_id)
            labels.append(label)
            print(client_id, label)
            continue

        if check_mrz(passport_per):
            print("Sorry! You are being rejected because the Passport MRZ is wrong.", client_id)
            rejected_ids.append(client_id)
            labels.append(label)
            continue

        if check_phonenumber(account_per, profile_per):
            print("Sorry! You are being rejected because the phone number is wrong.", client_id)
            rejected_ids.append(client_id)
            labels.append(label)
            continue

        if check_passport_dates(passport_per):  # Changed from account_form_pd
            print("Sorry! You are being rejected because the passport dates are wrong.", client_id)
            rejected_ids.append(client_id)
            labels.append(label)
            continue

        if check_address(account_per, profile_per):
            print("Sorry! You are being rejected because the postal code is wrong.", client_id)
            rejected_ids.append(client_id)
            labels.append(label)
            continue

        if check_email(account_per, profile_per):
            print("Sorry! You are being rejected because the email id is wrong.", client_id)
            rejected_ids.append(client_id)
            labels.append(label)
            continue

        if check_nationality(passport_per, account_per, profile_per):
            print("Sorry! You are being rejected because the nationality is wrong.", client_id)
            rejected_ids.append(client_id)
            labels.append(label)
            continue

        if check_country_of_domicile(account_per, profile_per):
            print("Sorry! You are being rejected because the country of domicile is wrong.", client_id)
            rejected_ids.append(client_id)
            labels.append(label)
            continue

        if check_birthdate(passport_per, profile_per):
            print("Sorry! You are being rejected because the birthdate is wrong.", client_id)
            rejected_ids.append(client_id)
            labels.append(label)
            continue

        if check_currency(account_per, profile_per):
            print("Sorry! You are being rejected because the currency is wrong.", client_id)
            rejected_ids.append(client_id)
            labels.append(label)
            continue

        if check_gender(passport_per, profile_per):
            print("Sorry! You are being rejected because the gender is wrong.", client_id)
            rejected_ids.append(client_id)
            labels.append(label)
            continue

        if check_real_estate_value(profile_per):
            print("Sorry! You are being rejected because the real estate value is wrong.", client_id)
            rejected_ids.append(client_id)
            labels.append(label)
            continue
        if check_multiple_countries(account_per, profile_per):
            print("Sorry! You are being rejected because the country of domicile is wrong.", client_id)
            rejected_ids.append(client_id)
            labels.append(label)
            print(client_id, label)
            continue
        if check_europe_postal_code(account_per, profile_per):
            print("Sorry! You are being rejected because the postal code is wrong.", client_id)
            rejected_ids.append(client_id)
            labels.append(label)
            print(client_id, label)
            continue
        if check_description(index, LLM_Model):
            print("Sorry! You are being rejected because the descrition", client_id)
            rejected_ids.append(client_id)
            labels.append(label)
            print(client_id, label)
            continue
        


    return rejected_ids,labels

# %%
LLM_Model = pipeline("text2text-generation", model="google/flan-t5-large")
# Out:
# config.json:   0%|          | 0.00/662 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/3.13G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/2.54k [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.42M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/2.20k [00:00<?, ?B/s]

# %%
reje_ids,labels = validate_data(passport_pd, account_form_pd, client_profile_pd,LLM_Model)

len(reje_ids)
# Out:
# Sorry! You are being rejected because the phone number is wrong. client_1
# Sorry! You are being rejected because the name is wrong. client_1004
# client_1004 Reject
# Sorry! You are being rejected because the Passport MRZ is wrong. client_1005
# Invalid postal code for Switzerland: nan
# client_1016 Reject
# Sorry! You are being rejected because the passport number is wrong. client_1017
# client_1017 Reject
# Sorry! You are being rejected because the phone number is wrong. client_1018
# Sorry! You are being rejected because the Passport MRZ is wrong. client_1029
# Sorry! You are being rejected because the Passport MRZ is wrong. client_1031
# Sorry! You are being rejected because the name is wrong. client_1033
# client_1033 Reject
# Sorry! You are being rejected because the Passport MRZ is wrong. client_1038
# Sorry! You are being rejected because the passport dates are wrong. client_1047
# Sorry! You are being rejected because the Passport MRZ is wrong. client_1049
# Sorry! You are being rejected because the Passport MRZ is wrong. client_1050
# Sorry! You are being rejected because the Passport MRZ is wrong. client_1052
# Sorry! You are being rejected because the email id is wrong. client_1056
# Sorry! You are being rejected because the phone number is wrong. client_1062
# Sorry! You are being rejected because the name is wrong. client_1063
# client_1063 Reject
# Invalid postal code for Italy: nan
# client_107 Reject
# Sorry! You are being rejected because the passport number is wrong. client_1070
# client_1070 Reject
# Sorry! You are being rejected because the nationality is wrong. client_1071
# Sorry! You are being rejected because the passport number is wrong. client_1072
# client_1072 Reject
# Sorry! You are being rejected because the phone number is wrong. client_1074
# Sorry! You are being rejected because the email id is wrong. client_1075
# Sorry! You are being rejected because the Passport MRZ is wrong. client_1076
# Sorry! You are being rejected because the postal code is wrong. client_1077
# Sorry! You are being rejected because the Passport MRZ is wrong. client_1084
# Sorry! You are being rejected because the name is wrong. client_109
# client_109 Reject
# Sorry! You are being rejected because the Passport MRZ is wrong. client_1090
# Sorry! You are being rejected because the Passport MRZ is wrong. client_1093
# Sorry! You are being rejected because the Passport MRZ is wrong. client_1096
# Sorry! You are being rejected because the name is wrong. client_1099
# client_1099 Reject
# Sorry! You are being rejected because the Passport MRZ is wrong. client_110
# Sorry! You are being rejected because the email id is wrong. client_1110
# Sorry! You are being rejected because the name is wrong. client_1116
# client_1116 Reject
# Sorry! You are being rejected because the Passport MRZ is wrong. client_1118
# Sorry! You are being rejected because the phone number is wrong. client_1120
# Sorry! You are being rejected because the Passport MRZ is wrong. client_1124
# Sorry! You are being rejected because the phone number is wrong. client_1132
# Sorry! You are being rejected because the postal code is wrong. client_1136
# Sorry! You are being rejected because the email id is wrong. client_1137
# Sorry! You are being rejected because the nationality is wrong. client_114
# Sorry! You are being rejected because the Passport MRZ is wrong. client_1140
# Sorry! You are being rejected because the currency is wrong. client_1143
# Sorry! You are being rejected because the phone number is wrong. client_1146
# Sorry! You are being rejected because the name is wrong. client_1147
# client_1147 Reject
# Sorry! You are being rejected because the phone number is wrong. client_1148
# Sorry! You are being rejected because the phone number is wrong. client_1152
# Sorry! You are being rejected because the name is wrong. client_1158
# client_1158 Reject
# Sorry! You are being rejected because the postal code is wrong. client_116
# Sorry! You are being rejected because the Passport MRZ is wrong. client_1161
# Sorry! You are being rejected because the passport number is wrong. client_1162
# client_1162 Reject
# Sorry! You are being rejected because the Passport MRZ is wrong. client_117
# Sorry! You are being rejected because the Passport MRZ is wrong. client_1179
# Sorry! You are being rejected because the Passport MRZ is wrong. client_1181
# Sorry! You are being rejected because the nationality is wrong. client_119
# Sorry! You are being rejected because the Passport MRZ is wrong. client_1194
# Sorry! You are being rejected because the Passport MRZ is wrong. client_1197
# Sorry! You are being rejected because the passport number is wrong. client_1198
# client_1198 Reject
# Sorry! You are being rejected because the Passport MRZ is wrong. client_1199
# Sorry! You are being rejected because the email id is wrong. client_1203
# Sorry! You are being rejected because the Passport MRZ is wrong. client_1205
# Invalid postal code for Denmark: nan
# client_1210 Reject
# Sorry! You are being rejected because the postal code is wrong. client_1215
# Sorry! You are being rejected because the Passport MRZ is wrong. client_1218
# Sorry! You are being rejected because the name is wrong. client_1221
# client_1221 Reject
# Sorry! You are being rejected because the nationality is wrong. client_1224
# Sorry! You are being rejected because the Passport MRZ is wrong. client_1226
# Sorry! You are being rejected because the Passport MRZ is wrong. client_1227
# Sorry! You are being rejected because the postal code is wrong. client_123
# Sorry! You are being rejected because the phone number is wrong. client_1232
# Sorry! You are being rejected because the email id is wrong. client_1233
# Sorry! You are being rejected because the Passport MRZ is wrong. client_1236
# Sorry! You are being rejected because the Passport MRZ is wrong. client_1238
# Sorry! You are being rejected because the phone number is wrong. client_1240
# Sorry! You are being rejected because the passport number is wrong. client_1248
# client_1248 Reject
# Sorry! You are being rejected because the passport number is wrong. client_1249
# client_1249 Reject
# Sorry! You are being rejected because the Passport MRZ is wrong. client_1253
# Sorry! You are being rejected because the postal code is wrong. client_1254
# Sorry! You are being rejected because the Passport MRZ is wrong. client_126
# Sorry! You are being rejected because the passport number is wrong. client_1262
# client_1262 Reject
# Sorry! You are being rejected because the nationality is wrong. client_1264
# Sorry! You are being rejected because the phone number is wrong. client_1271
# Sorry! You are being rejected because the postal code is wrong. client_1275
# Sorry! You are being rejected because the passport number is wrong. client_1280
# client_1280 Reject
# Sorry! You are being rejected because the Passport MRZ is wrong. client_1285
# Sorry! You are being rejected because the Passport MRZ is wrong. client_1288
# Sorry! You are being rejected because the country of domicile is wrong. client_1289
# Sorry! You are being rejected because the phone number is wrong. client_1290
# Sorry! You are being rejected because the Passport MRZ is wrong. client_1295
# Sorry! You are being rejected because the Passport MRZ is wrong. client_13
# Sorry! You are being rejected because the passport number is wrong. client_1303
# client_1303 Reject
# Sorry! You are being rejected because the Passport MRZ is wrong. client_1305
# Sorry! You are being rejected because the Passport MRZ is wrong. client_1307
# Sorry! You are being rejected because the name is wrong. client_1308
# client_1308 Reject
# Sorry! You are being rejected because the phone number is wrong. client_131
# Sorry! You are being rejected because the phone number is wrong. client_1310
# Sorry! You are being rejected because the Passport MRZ is wrong. client_1312
# Sorry! You are being rejected because the name is wrong. client_1316
# client_1316 Reject
# Sorry! You are being rejected because the phone number is wrong. client_1321
# Sorry! You are being rejected because the phone number is wrong. client_1324
# Sorry! You are being rejected because the phone number is wrong. client_1338
# Sorry! You are being rejected because the Passport MRZ is wrong. client_1340
# Sorry! You are being rejected because the postal code is wrong. client_1346
# Sorry! You are being rejected because the Passport MRZ is wrong. client_1366
# Sorry! You are being rejected because the phone number is wrong. client_1367
# Sorry! You are being rejected because the passport number is wrong. client_1370
# client_1370 Reject
# Sorry! You are being rejected because the phone number is wrong. client_1372
# Sorry! You are being rejected because the phone number is wrong. client_1378
# Sorry! You are being rejected because the phone number is wrong. client_138
# Sorry! You are being rejected because the postal code is wrong. client_1381
# Sorry! You are being rejected because the Passport MRZ is wrong. client_1383
# Sorry! You are being rejected because the name is wrong. client_1386
# client_1386 Reject
# Sorry! You are being rejected because the name is wrong. client_1389
# client_1389 Reject
# Sorry! You are being rejected because the Passport MRZ is wrong. client_1393
# Sorry! You are being rejected because the name is wrong. client_1396
# client_1396 Reject
# Sorry! You are being rejected because the Passport MRZ is wrong. client_1399
# Sorry! You are being rejected because the nationality is wrong. client_14
# Sorry! You are being rejected because the email id is wrong. client_1400
# Sorry! You are being rejected because the name is wrong. client_1409
# client_1409 Reject
# Sorry! You are being rejected because the passport dates are wrong. client_1411
# Sorry! You are being rejected because the Passport MRZ is wrong. client_1415
# Sorry! You are being rejected because the passport number is wrong. client_1416
# client_1416 Reject
# Sorry! You are being rejected because the passport number is wrong. client_1418
# client_1418 Reject
# Sorry! You are being rejected because the phone number is wrong. client_1419
# Sorry! You are being rejected because the birthdate is wrong. client_1422
# Sorry! You are being rejected because the passport dates are wrong. client_1423
# Sorry! You are being rejected because the phone number is wrong. client_1427
# Sorry! You are being rejected because the phone number is wrong. client_1429
# Sorry! You are being rejected because the name is wrong. client_1431
# client_1431 Reject
# Sorry! You are being rejected because the Passport MRZ is wrong. client_1432
# Sorry! You are being rejected because the Passport MRZ is wrong. client_1435
# Sorry! You are being rejected because the passport number is wrong. client_1441
# client_1441 Reject
# Sorry! You are being rejected because the phone number is wrong. client_1442
# Sorry! You are being rejected because the phone number is wrong. client_1443
# Sorry! You are being rejected because the name is wrong. client_1447
# client_1447 Reject
# Sorry! You are being rejected because the phone number is wrong. client_145
# Sorry! You are being rejected because the phone number is wrong. client_1451
# Sorry! You are being rejected because the phone number is wrong. client_1454
# Sorry! You are being rejected because the Passport MRZ is wrong. client_1456
# Sorry! You are being rejected because the Passport MRZ is wrong. client_146
# Sorry! You are being rejected because the currency is wrong. client_1461
# Sorry! You are being rejected because the phone number is wrong. client_1463
# Sorry! You are being rejected because the Passport MRZ is wrong. client_1474
# Sorry! You are being rejected because the birthdate is wrong. client_1475
# Sorry! You are being rejected because the nationality is wrong. client_1476
# Sorry! You are being rejected because the Passport MRZ is wrong. client_1477
# Sorry! You are being rejected because the Passport MRZ is wrong. client_1478
# Sorry! You are being rejected because the phone number is wrong. client_1481
# Sorry! You are being rejected because the gender is wrong. client_1482
# Sorry! You are being rejected because the postal code is wrong. client_1486
# Sorry! You are being rejected because the Passport MRZ is wrong. client_1491
# Sorry! You are being rejected because the passport number is wrong. client_1492
# client_1492 Reject
# Sorry! You are being rejected because the Passport MRZ is wrong. client_150
# Sorry! You are being rejected because the postal code is wrong. client_1504
# Sorry! You are being rejected because the passport number is wrong. client_1505
# client_1505 Reject
# Sorry! You are being rejected because the Passport MRZ is wrong. client_151
# Sorry! You are being rejected because the nationality is wrong. client_1512
# Sorry! You are being rejected because the name is wrong. client_1513
# client_1513 Reject
# Sorry! You are being rejected because the Passport MRZ is wrong. client_1518
# Sorry! You are being rejected because the Passport MRZ is wrong. client_1519
# Sorry! You are being rejected because the passport number is wrong. client_1521
# client_1521 Reject
# Sorry! You are being rejected because the phone number is wrong. client_1526
# Sorry! You are being rejected because the country of domicile is wrong. client_1527
# Sorry! You are being rejected because the postal code is wrong. client_1530
# Sorry! You are being rejected because the Passport MRZ is wrong. client_1538
# Sorry! You are being rejected because the name is wrong. client_1542
# client_1542 Reject
# Sorry! You are being rejected because the birthdate is wrong. client_1549
# Sorry! You are being rejected because the Passport MRZ is wrong. client_155
# Sorry! You are being rejected because the passport number is wrong. client_1555
# client_1555 Reject
# Sorry! You are being rejected because the name is wrong. client_1556
# client_1556 Reject
# Sorry! You are being rejected because the passport number is wrong. client_1561
# client_1561 Reject
# Sorry! You are being rejected because the Passport MRZ is wrong. client_1566
# Sorry! You are being rejected because the Passport MRZ is wrong. client_1568
# Sorry! You are being rejected because the Passport MRZ is wrong. client_1573
# Sorry! You are being rejected because the Passport MRZ is wrong. client_1574
# Sorry! You are being rejected because the name is wrong. client_1576
# client_1576 Reject
# Sorry! You are being rejected because the phone number is wrong. client_1578
# Sorry! You are being rejected because the country of domicile is wrong. client_1579
# Sorry! You are being rejected because the Passport MRZ is wrong. client_1580
# Sorry! You are being rejected because the phone number is wrong. client_1582
# Sorry! You are being rejected because the Passport MRZ is wrong. client_1584
# Sorry! You are being rejected because the passport number is wrong. client_1588
# client_1588 Reject
# Sorry! You are being rejected because the Passport MRZ is wrong. client_1589
# Sorry! You are being rejected because the phone number is wrong. client_1591
# Sorry! You are being rejected because the Passport MRZ is wrong. client_1593
# Sorry! You are being rejected because the Passport MRZ is wrong. client_1594
# Sorry! You are being rejected because the Passport MRZ is wrong. client_1599
# Sorry! You are being rejected because the Passport MRZ is wrong. client_16
# Sorry! You are being rejected because the Passport MRZ is wrong. client_160
# Sorry! You are being rejected because the phone number is wrong. client_1601
# Sorry! You are being rejected because the Passport MRZ is wrong. client_1603
# Sorry! You are being rejected because the email id is wrong. client_1605
# Sorry! You are being rejected because the postal code is wrong. client_1608
# Sorry! You are being rejected because the phone number is wrong. client_1610
# Sorry! You are being rejected because the email id is wrong. client_1611
# Sorry! You are being rejected because the birthdate is wrong. client_1612
# Sorry! You are being rejected because the phone number is wrong. client_1616
# Sorry! You are being rejected because the currency is wrong. client_162
# Sorry! You are being rejected because the Passport MRZ is wrong. client_1621
# Sorry! You are being rejected because the phone number is wrong. client_1625
# Sorry! You are being rejected because the Passport MRZ is wrong. client_1628
# Sorry! You are being rejected because the name is wrong. client_1632
# client_1632 Reject
# Sorry! You are being rejected because the passport number is wrong. client_1635
# client_1635 Reject
# Sorry! You are being rejected because the Passport MRZ is wrong. client_1637
# Sorry! You are being rejected because the Passport MRZ is wrong. client_1647
# Sorry! You are being rejected because the passport number is wrong. client_1649
# client_1649 Reject
# Sorry! You are being rejected because the name is wrong. client_165
# client_165 Reject
# Sorry! You are being rejected because the phone number is wrong. client_1651
# Sorry! You are being rejected because the phone number is wrong. client_1654
# Sorry! You are being rejected because the passport number is wrong. client_1655
# client_1655 Reject
# Sorry! You are being rejected because the postal code is wrong. client_1661
# Sorry! You are being rejected because the name is wrong. client_1668
# client_1668 Reject
# Sorry! You are being rejected because the email id is wrong. client_1673
# Sorry! You are being rejected because the Passport MRZ is wrong. client_1675
# Sorry! You are being rejected because the passport number is wrong. client_168
# client_168 Reject
# Sorry! You are being rejected because the Passport MRZ is wrong. client_1688
# Sorry! You are being rejected because the Passport MRZ is wrong. client_1690
# Sorry! You are being rejected because the postal code is wrong. client_1695
# Sorry! You are being rejected because the name is wrong. client_1696
# client_1696 Reject
# Sorry! You are being rejected because the Passport MRZ is wrong. client_1698
# Sorry! You are being rejected because the phone number is wrong. client_170
# Sorry! You are being rejected because the phone number is wrong. client_1701
# Invalid postal code for Germany: nan
# client_1705 Reject
# Sorry! You are being rejected because the country of domicile is wrong. client_1706
# Sorry! You are being rejected because the phone number is wrong. client_1707
# Sorry! You are being rejected because the passport number is wrong. client_1712
# client_1712 Reject
# Sorry! You are being rejected because the Passport MRZ is wrong. client_1713
# Sorry! You are being rejected because the phone number is wrong. client_1717
# Sorry! You are being rejected because the Passport MRZ is wrong. client_1718
# Sorry! You are being rejected because the phone number is wrong. client_172
# Sorry! You are being rejected because the Passport MRZ is wrong. client_1721
# Sorry! You are being rejected because the Passport MRZ is wrong. client_1722
# Sorry! You are being rejected because the Passport MRZ is wrong. client_1730
# Sorry! You are being rejected because the postal code is wrong. client_1731
# Sorry! You are being rejected because the currency is wrong. client_1732
# Sorry! You are being rejected because the phone number is wrong. client_1734
# Sorry! You are being rejected because the phone number is wrong. client_1739
# Sorry! You are being rejected because the phone number is wrong. client_1742
# Sorry! You are being rejected because the Passport MRZ is wrong. client_1745
# Sorry! You are being rejected because the Passport MRZ is wrong. client_1750
# Sorry! You are being rejected because the Passport MRZ is wrong. client_1752
# Sorry! You are being rejected because the Passport MRZ is wrong. client_1754
# Sorry! You are being rejected because the Passport MRZ is wrong. client_1755
# Sorry! You are being rejected because the Passport MRZ is wrong. client_1758
# Sorry! You are being rejected because the Passport MRZ is wrong. client_1759
# Sorry! You are being rejected because the Passport MRZ is wrong. client_176
# Sorry! You are being rejected because the name is wrong. client_1760
# client_1760 Reject
# Sorry! You are being rejected because the Passport MRZ is wrong. client_1761
# Sorry! You are being rejected because the Passport MRZ is wrong. client_1763
# Sorry! You are being rejected because the Passport MRZ is wrong. client_1764
# Sorry! You are being rejected because the Passport MRZ is wrong. client_1767
# Sorry! You are being rejected because the name is wrong. client_1770
# client_1770 Reject
# Sorry! You are being rejected because the passport number is wrong. client_1773
# client_1773 Reject
# Sorry! You are being rejected because the Passport MRZ is wrong. client_1774
# Sorry! You are being rejected because the phone number is wrong. client_1775
# Sorry! You are being rejected because the phone number is wrong. client_1777
# Sorry! You are being rejected because the Passport MRZ is wrong. client_1784
# Sorry! You are being rejected because the passport number is wrong. client_1786
# client_1786 Reject
# Sorry! You are being rejected because the postal code is wrong. client_1791
# Sorry! You are being rejected because the country of domicile is wrong. client_18
# Sorry! You are being rejected because the Passport MRZ is wrong. client_180
# Sorry! You are being rejected because the postal code is wrong. client_1801
# Sorry! You are being rejected because the passport number is wrong. client_1802
# client_1802 Reject
# Sorry! You are being rejected because the passport number is wrong. client_1804
# client_1804 Reject
# Sorry! You are being rejected because the passport number is wrong. client_1806
# client_1806 Reject
# Sorry! You are being rejected because the nationality is wrong. client_1807
# Sorry! You are being rejected because the phone number is wrong. client_1808
# Sorry! You are being rejected because the Passport MRZ is wrong. client_181
# Sorry! You are being rejected because the Passport MRZ is wrong. client_1811
# Sorry! You are being rejected because the Passport MRZ is wrong. client_1812
# Sorry! You are being rejected because the passport number is wrong. client_1815
# client_1815 Reject
# Sorry! You are being rejected because the currency is wrong. client_1818
# Sorry! You are being rejected because the Passport MRZ is wrong. client_1819
# Sorry! You are being rejected because the postal code is wrong. client_1823
# Sorry! You are being rejected because the phone number is wrong. client_1825
# Sorry! You are being rejected because the phone number is wrong. client_1828
# Sorry! You are being rejected because the passport number is wrong. client_1829
# client_1829 Reject
# Sorry! You are being rejected because the Passport MRZ is wrong. client_1830
# Sorry! You are being rejected because the postal code is wrong. client_1831
# Sorry! You are being rejected because the nationality is wrong. client_1833
# Sorry! You are being rejected because the Passport MRZ is wrong. client_1836
# Sorry! You are being rejected because the Passport MRZ is wrong. client_1839
# Sorry! You are being rejected because the Passport MRZ is wrong. client_1842
# Sorry! You are being rejected because the postal code is wrong. client_1843
# Sorry! You are being rejected because the postal code is wrong. client_1845
# Sorry! You are being rejected because the postal code is wrong. client_1848
# Sorry! You are being rejected because the Passport MRZ is wrong. client_1852
# Sorry! You are being rejected because the birthdate is wrong. client_1853
# Invalid postal code for Finland: nan
# client_1867 Reject
# Sorry! You are being rejected because the Passport MRZ is wrong. client_1874
# Sorry! You are being rejected because the phone number is wrong. client_1875
# Sorry! You are being rejected because the Passport MRZ is wrong. client_1876
# Sorry! You are being rejected because the Passport MRZ is wrong. client_1878
# Sorry! You are being rejected because the name is wrong. client_1882
# client_1882 Reject
# Sorry! You are being rejected because the name is wrong. client_1883
# client_1883 Reject
# Sorry! You are being rejected because the Passport MRZ is wrong. client_1884
# Sorry! You are being rejected because the Passport MRZ is wrong. client_1888
# Sorry! You are being rejected because the gender is wrong. client_1890
# Sorry! You are being rejected because the country of domicile is wrong. client_1891
# Sorry! You are being rejected because the Passport MRZ is wrong. client_1906
# Sorry! You are being rejected because the Passport MRZ is wrong. client_1907
# Sorry! You are being rejected because the name is wrong. client_1915
# client_1915 Reject
# Sorry! You are being rejected because the passport number is wrong. client_1919
# client_1919 Reject
# Sorry! You are being rejected because the phone number is wrong. client_1927
# Sorry! You are being rejected because the passport number is wrong. client_1928
# client_1928 Reject
# Sorry! You are being rejected because the passport number is wrong. client_1931
# client_1931 Reject
# Sorry! You are being rejected because the Passport MRZ is wrong. client_1936
# Sorry! You are being rejected because the Passport MRZ is wrong. client_1939
# Sorry! You are being rejected because the passport number is wrong. client_1943
# client_1943 Reject
# Sorry! You are being rejected because the Passport MRZ is wrong. client_1944
# Sorry! You are being rejected because the name is wrong. client_1945
# client_1945 Reject
# Sorry! You are being rejected because the country of domicile is wrong. client_1950
# Sorry! You are being rejected because the Passport MRZ is wrong. client_1956
# Sorry! You are being rejected because the passport number is wrong. client_1958
# client_1958 Reject
# Sorry! You are being rejected because the postal code is wrong. client_1961
# Sorry! You are being rejected because the name is wrong. client_1964
# client_1964 Reject
# Sorry! You are being rejected because the passport number is wrong. client_1972
# client_1972 Reject
# Sorry! You are being rejected because the phone number is wrong. client_1977
# Sorry! You are being rejected because the gender is wrong. client_1984
# Sorry! You are being rejected because the phone number is wrong. client_1989
# Sorry! You are being rejected because the Passport MRZ is wrong. client_1994
# Sorry! You are being rejected because the phone number is wrong. client_1998
# Sorry! You are being rejected because the name is wrong. client_2
# client_2 Reject
# Sorry! You are being rejected because the name is wrong. client_2002
# client_2002 Reject
# Sorry! You are being rejected because the Passport MRZ is wrong. client_2007
# Sorry! You are being rejected because the Passport MRZ is wrong. client_201
# Sorry! You are being rejected because the postal code is wrong. client_2011
# Sorry! You are being rejected because the phone number is wrong. client_2012
# Sorry! You are being rejected because the Passport MRZ is wrong. client_2013
# Sorry! You are being rejected because the Passport MRZ is wrong. client_2016
# Sorry! You are being rejected because the passport number is wrong. client_2023
# client_2023 Reject
# Sorry! You are being rejected because the Passport MRZ is wrong. client_2024
# Sorry! You are being rejected because the phone number is wrong. client_2025
# Sorry! You are being rejected because the Passport MRZ is wrong. client_2040
# Sorry! You are being rejected because the passport number is wrong. client_2041
# client_2041 Reject
# Sorry! You are being rejected because the email id is wrong. client_2045
# Sorry! You are being rejected because the phone number is wrong. client_2049
# Sorry! You are being rejected because the name is wrong. client_2050
# client_2050 Reject
# Sorry! You are being rejected because the phone number is wrong. client_2053
# Sorry! You are being rejected because the Passport MRZ is wrong. client_2054
# Sorry! You are being rejected because the Passport MRZ is wrong. client_2056
# Sorry! You are being rejected because the postal code is wrong. client_2060
# Sorry! You are being rejected because the Passport MRZ is wrong. client_2062
# Sorry! You are being rejected because the Passport MRZ is wrong. client_2064
# Sorry! You are being rejected because the name is wrong. client_2069
# client_2069 Reject
# Sorry! You are being rejected because the email id is wrong. client_2072
# Sorry! You are being rejected because the nationality is wrong. client_2080
# Sorry! You are being rejected because the Passport MRZ is wrong. client_2082
# Sorry! You are being rejected because the birthdate is wrong. client_2083
# Sorry! You are being rejected because the Passport MRZ is wrong. client_2091
# Sorry! You are being rejected because the passport dates are wrong. client_2094
# Sorry! You are being rejected because the Passport MRZ is wrong. client_2108
# Sorry! You are being rejected because the passport number is wrong. client_2110
# client_2110 Reject
# Sorry! You are being rejected because the phone number is wrong. client_2111
# Sorry! You are being rejected because the phone number is wrong. client_2113
# Sorry! You are being rejected because the Passport MRZ is wrong. client_2115
# Sorry! You are being rejected because the nationality is wrong. client_2122
# Sorry! You are being rejected because the nationality is wrong. client_2125
# Sorry! You are being rejected because the Passport MRZ is wrong. client_2126
# Sorry! You are being rejected because the passport number is wrong. client_2127
# client_2127 Reject
# Sorry! You are being rejected because the Passport MRZ is wrong. client_2130
# Sorry! You are being rejected because the nationality is wrong. client_2134
# Sorry! You are being rejected because the phone number is wrong. client_2136
# Sorry! You are being rejected because the passport number is wrong. client_2141
# client_2141 Reject
# Sorry! You are being rejected because the email id is wrong. client_2142
# Sorry! You are being rejected because the Passport MRZ is wrong. client_2146
# Sorry! You are being rejected because the name is wrong. client_2147
# client_2147 Reject
# Sorry! You are being rejected because the Passport MRZ is wrong. client_2149
# Sorry! You are being rejected because the phone number is wrong. client_2152
# Sorry! You are being rejected because the passport number is wrong. client_2154
# client_2154 Reject
# Sorry! You are being rejected because the phone number is wrong. client_2158
# Sorry! You are being rejected because the gender is wrong. client_2159
# Sorry! You are being rejected because the Passport MRZ is wrong. client_216
# Sorry! You are being rejected because the country of domicile is wrong. client_2163
# Sorry! You are being rejected because the Passport MRZ is wrong. client_2164
# Sorry! You are being rejected because the email id is wrong. client_2169
# Sorry! You are being rejected because the postal code is wrong. client_2177
# Sorry! You are being rejected because the gender is wrong. client_218
# Sorry! You are being rejected because the birthdate is wrong. client_2183
# Sorry! You are being rejected because the Passport MRZ is wrong. client_2187
# Sorry! You are being rejected because the postal code is wrong. client_2189
# Sorry! You are being rejected because the Passport MRZ is wrong. client_219
# Sorry! You are being rejected because the Passport MRZ is wrong. client_2190
# Sorry! You are being rejected because the name is wrong. client_2195
# client_2195 Reject
# Sorry! You are being rejected because the phone number is wrong. client_2199
# Sorry! You are being rejected because the country of domicile is wrong. client_22
# Sorry! You are being rejected because the country of domicile is wrong. client_220
# Sorry! You are being rejected because the passport number is wrong. client_2201
# client_2201 Reject
# Sorry! You are being rejected because the postal code is wrong. client_2205
# Sorry! You are being rejected because the Passport MRZ is wrong. client_2208
# Sorry! You are being rejected because the phone number is wrong. client_2209
# Sorry! You are being rejected because the birthdate is wrong. client_2210
# Sorry! You are being rejected because the Passport MRZ is wrong. client_2212
# Sorry! You are being rejected because the name is wrong. client_2214
# client_2214 Reject
# Sorry! You are being rejected because the country of domicile is wrong. client_2216
# Sorry! You are being rejected because the phone number is wrong. client_2218
# Sorry! You are being rejected because the name is wrong. client_2219
# client_2219 Reject
# Sorry! You are being rejected because the Passport MRZ is wrong. client_2222
# Sorry! You are being rejected because the name is wrong. client_2224
# client_2224 Reject
# Sorry! You are being rejected because the name is wrong. client_2225
# client_2225 Reject
# Sorry! You are being rejected because the Passport MRZ is wrong. client_2226
# Sorry! You are being rejected because the phone number is wrong. client_2228
# Sorry! You are being rejected because the name is wrong. client_2230
# client_2230 Reject
# Sorry! You are being rejected because the birthdate is wrong. client_2232
# Sorry! You are being rejected because the Passport MRZ is wrong. client_2234
# Sorry! You are being rejected because the Passport MRZ is wrong. client_2235
# Sorry! You are being rejected because the passport number is wrong. client_2245
# client_2245 Reject
# Sorry! You are being rejected because the birthdate is wrong. client_2247
# Sorry! You are being rejected because the email id is wrong. client_2249
# Sorry! You are being rejected because the phone number is wrong. client_225
# Sorry! You are being rejected because the phone number is wrong. client_2254
# Sorry! You are being rejected because the Passport MRZ is wrong. client_2255
# Sorry! You are being rejected because the passport number is wrong. client_2256
# client_2256 Reject
# Sorry! You are being rejected because the postal code is wrong. client_2261
# Sorry! You are being rejected because the postal code is wrong. client_2262
# Sorry! You are being rejected because the Passport MRZ is wrong. client_2264
# Sorry! You are being rejected because the Passport MRZ is wrong. client_2265
# Sorry! You are being rejected because the phone number is wrong. client_2268
# Sorry! You are being rejected because the Passport MRZ is wrong. client_2275
# Sorry! You are being rejected because the phone number is wrong. client_2279
# Sorry! You are being rejected because the passport number is wrong. client_2282
# client_2282 Reject
# Sorry! You are being rejected because the Passport MRZ is wrong. client_2287
# Sorry! You are being rejected because the passport number is wrong. client_2289
# client_2289 Reject
# Sorry! You are being rejected because the Passport MRZ is wrong. client_2291
# Sorry! You are being rejected because the passport number is wrong. client_2296
# client_2296 Reject
# Sorry! You are being rejected because the name is wrong. client_2300
# client_2300 Reject
# Sorry! You are being rejected because the Passport MRZ is wrong. client_2301
# Sorry! You are being rejected because the postal code is wrong. client_2304
# Sorry! You are being rejected because the name is wrong. client_2305
# client_2305 Reject
# Sorry! You are being rejected because the name is wrong. client_2306
# client_2306 Reject
# Sorry! You are being rejected because the Passport MRZ is wrong. client_2312
# Sorry! You are being rejected because the Passport MRZ is wrong. client_2313
# Sorry! You are being rejected because the phone number is wrong. client_2314
# Sorry! You are being rejected because the nationality is wrong. client_2316
# Sorry! You are being rejected because the phone number is wrong. client_2318
# Sorry! You are being rejected because the name is wrong. client_2321
# client_2321 Reject
# Sorry! You are being rejected because the Passport MRZ is wrong. client_2323
# Sorry! You are being rejected because the phone number is wrong. client_2325
# Sorry! You are being rejected because the phone number is wrong. client_2328
# Sorry! You are being rejected because the phone number is wrong. client_2330
# Sorry! You are being rejected because the birthdate is wrong. client_2331
# Sorry! You are being rejected because the passport number is wrong. client_2332
# client_2332 Reject
# Sorry! You are being rejected because the nationality is wrong. client_2340
# Sorry! You are being rejected because the name is wrong. client_2343
# client_2343 Reject
# Sorry! You are being rejected because the Passport MRZ is wrong. client_2349
# Sorry! You are being rejected because the nationality is wrong. client_2352
# Sorry! You are being rejected because the country of domicile is wrong. client_2354
# Sorry! You are being rejected because the passport number is wrong. client_2360
# client_2360 Reject
# Sorry! You are being rejected because the passport number is wrong. client_2362
# client_2362 Reject
# Sorry! You are being rejected because the name is wrong. client_2371
# client_2371 Reject
# Sorry! You are being rejected because the country of domicile is wrong. client_2372
# Sorry! You are being rejected because the currency is wrong. client_2377
# Sorry! You are being rejected because the passport number is wrong. client_238
# client_238 Reject
# Sorry! You are being rejected because the Passport MRZ is wrong. client_2381
# Sorry! You are being rejected because the Passport MRZ is wrong. client_2387
# Sorry! You are being rejected because the phone number is wrong. client_239
# Sorry! You are being rejected because the passport number is wrong. client_2391
# client_2391 Reject
# Sorry! You are being rejected because the name is wrong. client_2393
# client_2393 Reject
# Sorry! You are being rejected because the phone number is wrong. client_2394
# Sorry! You are being rejected because the name is wrong. client_2398
# client_2398 Reject
# Sorry! You are being rejected because the phone number is wrong. client_240
# Sorry! You are being rejected because the birthdate is wrong. client_2401
# Sorry! You are being rejected because the passport number is wrong. client_2405
# client_2405 Reject
# Sorry! You are being rejected because the Passport MRZ is wrong. client_2408
# Sorry! You are being rejected because the Passport MRZ is wrong. client_2410
# Sorry! You are being rejected because the phone number is wrong. client_2412
# Sorry! You are being rejected because the passport number is wrong. client_2418
# client_2418 Reject
# Sorry! You are being rejected because the Passport MRZ is wrong. client_2423
# Sorry! You are being rejected because the phone number is wrong. client_2425
# Sorry! You are being rejected because the passport number is wrong. client_2426
# client_2426 Reject
# Sorry! You are being rejected because the passport number is wrong. client_2429
# client_2429 Reject
# Sorry! You are being rejected because the passport number is wrong. client_2435
# client_2435 Reject
# Sorry! You are being rejected because the Passport MRZ is wrong. client_2436
# Sorry! You are being rejected because the phone number is wrong. client_2437
# Sorry! You are being rejected because the passport number is wrong. client_2441
# client_2441 Reject
# Sorry! You are being rejected because the phone number is wrong. client_2444
# Sorry! You are being rejected because the Passport MRZ is wrong. client_2448
# Sorry! You are being rejected because the phone number is wrong. client_2449
# Sorry! You are being rejected because the name is wrong. client_2456
# client_2456 Reject
# Sorry! You are being rejected because the passport number is wrong. client_2459
# client_2459 Reject
# Sorry! You are being rejected because the Passport MRZ is wrong. client_246
# Sorry! You are being rejected because the birthdate is wrong. client_2465
# Sorry! You are being rejected because the Passport MRZ is wrong. client_247
# Sorry! You are being rejected because the Passport MRZ is wrong. client_2472
# Sorry! You are being rejected because the postal code is wrong. client_2474
# Sorry! You are being rejected because the passport number is wrong. client_2475
# client_2475 Reject
# Sorry! You are being rejected because the Passport MRZ is wrong. client_2478
# Sorry! You are being rejected because the name is wrong. client_2482
# client_2482 Reject
# Sorry! You are being rejected because the currency is wrong. client_2483
# Sorry! You are being rejected because the Passport MRZ is wrong. client_2485
# Sorry! You are being rejected because the Passport MRZ is wrong. client_2486
# Sorry! You are being rejected because the phone number is wrong. client_2487
# Sorry! You are being rejected because the name is wrong. client_2493
# client_2493 Reject
# Sorry! You are being rejected because the phone number is wrong. client_2494
# Sorry! You are being rejected because the passport number is wrong. client_2495
# client_2495 Reject
# Sorry! You are being rejected because the Passport MRZ is wrong. client_250
# Sorry! You are being rejected because the passport number is wrong. client_2507
# client_2507 Reject
# Sorry! You are being rejected because the birthdate is wrong. client_2508
# Sorry! You are being rejected because the name is wrong. client_2511
# client_2511 Reject
# Sorry! You are being rejected because the postal code is wrong. client_2514
# Sorry! You are being rejected because the Passport MRZ is wrong. client_2516
# Sorry! You are being rejected because the name is wrong. client_2517
# client_2517 Reject
# Sorry! You are being rejected because the email id is wrong. client_2518
# Sorry! You are being rejected because the name is wrong. client_2522
# client_2522 Reject
# Sorry! You are being rejected because the phone number is wrong. client_2527
# Sorry! You are being rejected because the phone number is wrong. client_2528
# Sorry! You are being rejected because the passport number is wrong. client_2534
# client_2534 Reject
# Sorry! You are being rejected because the passport number is wrong. client_2535
# client_2535 Reject
# Sorry! You are being rejected because the passport number is wrong. client_2536
# client_2536 Reject
# Sorry! You are being rejected because the phone number is wrong. client_2540
# Sorry! You are being rejected because the country of domicile is wrong. client_2547
# Sorry! You are being rejected because the name is wrong. client_255
# client_255 Reject
# Sorry! You are being rejected because the passport number is wrong. client_2552
# client_2552 Reject
# Sorry! You are being rejected because the postal code is wrong. client_2558
# Sorry! You are being rejected because the Passport MRZ is wrong. client_2561
# Sorry! You are being rejected because the email id is wrong. client_2568
# Invalid postal code for Belgium: nan
# client_2579 Reject
# Sorry! You are being rejected because the Passport MRZ is wrong. client_2581
# Sorry! You are being rejected because the passport number is wrong. client_2582
# client_2582 Reject
# Sorry! You are being rejected because the Passport MRZ is wrong. client_2587
# Sorry! You are being rejected because the email id is wrong. client_2588
# Sorry! You are being rejected because the name is wrong. client_2593
# client_2593 Reject
# Sorry! You are being rejected because the phone number is wrong. client_2594
# Sorry! You are being rejected because the postal code is wrong. client_2595
# Sorry! You are being rejected because the Passport MRZ is wrong. client_2597
# Sorry! You are being rejected because the phone number is wrong. client_2598
# Sorry! You are being rejected because the gender is wrong. client_2600
# Sorry! You are being rejected because the Passport MRZ is wrong. client_2604
# Sorry! You are being rejected because the Passport MRZ is wrong. client_2607
# Sorry! You are being rejected because the passport number is wrong. client_2614
# client_2614 Reject
# Sorry! You are being rejected because the phone number is wrong. client_262
# Sorry! You are being rejected because the birthdate is wrong. client_2623
# Sorry! You are being rejected because the passport number is wrong. client_2627
# client_2627 Reject
# Sorry! You are being rejected because the passport number is wrong. client_2635
# client_2635 Reject
# Sorry! You are being rejected because the Passport MRZ is wrong. client_2636
# Sorry! You are being rejected because the Passport MRZ is wrong. client_2639
# Sorry! You are being rejected because the gender is wrong. client_2644
# Sorry! You are being rejected because the Passport MRZ is wrong. client_2646
# Sorry! You are being rejected because the passport number is wrong. client_2649
# client_2649 Reject
# Sorry! You are being rejected because the email id is wrong. client_2650
# Sorry! You are being rejected because the nationality is wrong. client_2652
# Sorry! You are being rejected because the passport number is wrong. client_2657
# client_2657 Reject
# Sorry! You are being rejected because the passport number is wrong. client_2658
# client_2658 Reject
# Sorry! You are being rejected because the postal code is wrong. client_266
# Sorry! You are being rejected because the birthdate is wrong. client_2662
# Sorry! You are being rejected because the phone number is wrong. client_2666
# Sorry! You are being rejected because the name is wrong. client_267
# client_267 Reject
# Sorry! You are being rejected because the Passport MRZ is wrong. client_2670
# Sorry! You are being rejected because the passport number is wrong. client_2671
# client_2671 Reject
# Sorry! You are being rejected because the Passport MRZ is wrong. client_2675
# Sorry! You are being rejected because the currency is wrong. client_2685
# Sorry! You are being rejected because the name is wrong. client_269
# client_269 Reject
# Sorry! You are being rejected because the Passport MRZ is wrong. client_2690
# Sorry! You are being rejected because the Passport MRZ is wrong. client_2692
# Sorry! You are being rejected because the phone number is wrong. client_2693
# Sorry! You are being rejected because the email id is wrong. client_2696
# Sorry! You are being rejected because the phone number is wrong. client_2699
# Sorry! You are being rejected because the Passport MRZ is wrong. client_2701
# Sorry! You are being rejected because the nationality is wrong. client_2709
# Sorry! You are being rejected because the Passport MRZ is wrong. client_2715
# Sorry! You are being rejected because the passport number is wrong. client_272
# client_272 Reject
# Sorry! You are being rejected because the name is wrong. client_2722
# client_2722 Reject
# Sorry! You are being rejected because the Passport MRZ is wrong. client_2723
# Sorry! You are being rejected because the Passport MRZ is wrong. client_2725
# Sorry! You are being rejected because the Passport MRZ is wrong. client_2727
# Sorry! You are being rejected because the Passport MRZ is wrong. client_2739
# Sorry! You are being rejected because the name is wrong. client_2740
# client_2740 Reject
# Sorry! You are being rejected because the Passport MRZ is wrong. client_2741
# Sorry! You are being rejected because the email id is wrong. client_2742
# Sorry! You are being rejected because the postal code is wrong. client_2743
# Sorry! You are being rejected because the postal code is wrong. client_2752
# Sorry! You are being rejected because the phone number is wrong. client_2755
# Sorry! You are being rejected because the postal code is wrong. client_2762
# Sorry! You are being rejected because the phone number is wrong. client_2763
# Sorry! You are being rejected because the phone number is wrong. client_2764
# Sorry! You are being rejected because the Passport MRZ is wrong. client_2776
# Sorry! You are being rejected because the Passport MRZ is wrong. client_2779
# Sorry! You are being rejected because the passport number is wrong. client_2781
# client_2781 Reject
# Sorry! You are being rejected because the Passport MRZ is wrong. client_2782
# Sorry! You are being rejected because the nationality is wrong. client_2797
# Sorry! You are being rejected because the Passport MRZ is wrong. client_2799
# Sorry! You are being rejected because the name is wrong. client_280
# client_280 Reject
# Sorry! You are being rejected because the Passport MRZ is wrong. client_2804
# Sorry! You are being rejected because the name is wrong. client_2810
# client_2810 Reject
# Sorry! You are being rejected because the phone number is wrong. client_2811
# Sorry! You are being rejected because the Passport MRZ is wrong. client_2816
# Sorry! You are being rejected because the passport number is wrong. client_2818
# client_2818 Reject
# Sorry! You are being rejected because the Passport MRZ is wrong. client_2821
# Sorry! You are being rejected because the birthdate is wrong. client_2825
# Sorry! You are being rejected because the phone number is wrong. client_2834
# Sorry! You are being rejected because the birthdate is wrong. client_2836
# Sorry! You are being rejected because the birthdate is wrong. client_2837
# Sorry! You are being rejected because the passport number is wrong. client_2841
# client_2841 Reject
# Sorry! You are being rejected because the country of domicile is wrong. client_2843
# Sorry! You are being rejected because the Passport MRZ is wrong. client_286
# ...
# Sorry! You are being rejected because the Passport MRZ is wrong. client_9396
# Sorry! You are being rejected because the passport number is wrong. client_9402
# client_9402 Reject
# Sorry! You are being rejected because the passport number is wrong. client_9404
# client_9404 Reject
# Sorry! You are being rejected because the name is wrong. client_9409
# client_9409 Reject
# Sorry! You are being rejected because the Passport MRZ is wrong. client_9410
# Sorry! You are being rejected because the country of domicile is wrong. client_9411
# Sorry! You are being rejected because the phone number is wrong. client_9415
# Sorry! You are being rejected because the name is wrong. client_9419
# client_9419 Reject
# Sorry! You are being rejected because the phone number is wrong. client_9421
# Sorry! You are being rejected because the name is wrong. client_9427
# client_9427 Reject
# Sorry! You are being rejected because the Passport MRZ is wrong. client_9428
# Sorry! You are being rejected because the phone number is wrong. client_9429
# Sorry! You are being rejected because the Passport MRZ is wrong. client_9435
# Sorry! You are being rejected because the passport number is wrong. client_9440
# client_9440 Reject
# Sorry! You are being rejected because the email id is wrong. client_9443
# Sorry! You are being rejected because the currency is wrong. client_945
# Sorry! You are being rejected because the passport number is wrong. client_9450
# client_9450 Reject
# Sorry! You are being rejected because the Passport MRZ is wrong. client_9452
# Sorry! You are being rejected because the name is wrong. client_9455
# client_9455 Reject
# Sorry! You are being rejected because the nationality is wrong. client_946
# Sorry! You are being rejected because the phone number is wrong. client_9460
# Sorry! You are being rejected because the Passport MRZ is wrong. client_9461
# Sorry! You are being rejected because the name is wrong. client_9463
# client_9463 Reject
# Sorry! You are being rejected because the Passport MRZ is wrong. client_9467
# Sorry! You are being rejected because the Passport MRZ is wrong. client_9469
# Sorry! You are being rejected because the email id is wrong. client_9471
# Sorry! You are being rejected because the Passport MRZ is wrong. client_9475
# Sorry! You are being rejected because the passport number is wrong. client_9476
# client_9476 Reject
# Sorry! You are being rejected because the name is wrong. client_9477
# client_9477 Reject
# Sorry! You are being rejected because the passport number is wrong. client_9480
# client_9480 Reject
# Sorry! You are being rejected because the Passport MRZ is wrong. client_9483
# Sorry! You are being rejected because the name is wrong. client_9488
# client_9488 Reject
# Sorry! You are being rejected because the phone number is wrong. client_9489
# Sorry! You are being rejected because the Passport MRZ is wrong. client_9497
# Sorry! You are being rejected because the phone number is wrong. client_9500
# Sorry! You are being rejected because the country of domicile is wrong. client_9501
# Sorry! You are being rejected because the name is wrong. client_9502
# client_9502 Reject
# Sorry! You are being rejected because the name is wrong. client_9505
# client_9505 Reject
# Sorry! You are being rejected because the Passport MRZ is wrong. client_9514
# Sorry! You are being rejected because the Passport MRZ is wrong. client_9521
# Sorry! You are being rejected because the country of domicile is wrong. client_9524
# Sorry! You are being rejected because the phone number is wrong. client_9529
# Sorry! You are being rejected because the phone number is wrong. client_9535
# Sorry! You are being rejected because the email id is wrong. client_9536
# Sorry! You are being rejected because the phone number is wrong. client_9540
# Sorry! You are being rejected because the Passport MRZ is wrong. client_9541
# Sorry! You are being rejected because the Passport MRZ is wrong. client_9545
# Sorry! You are being rejected because the passport number is wrong. client_9548
# client_9548 Reject
# Sorry! You are being rejected because the country of domicile is wrong. client_955
# Sorry! You are being rejected because the phone number is wrong. client_9551
# Sorry! You are being rejected because the email id is wrong. client_9553
# Sorry! You are being rejected because the Passport MRZ is wrong. client_9555
# Sorry! You are being rejected because the nationality is wrong. client_9556
# Sorry! You are being rejected because the Passport MRZ is wrong. client_9573
# Sorry! You are being rejected because the passport dates are wrong. client_9575
# Sorry! You are being rejected because the phone number is wrong. client_9576
# Sorry! You are being rejected because the passport number is wrong. client_9578
# client_9578 Reject
# Sorry! You are being rejected because the gender is wrong. client_9579
# Sorry! You are being rejected because the Passport MRZ is wrong. client_9580
# Sorry! You are being rejected because the gender is wrong. client_9583
# Sorry! You are being rejected because the country of domicile is wrong. client_9584
# Sorry! You are being rejected because the phone number is wrong. client_9585
# Sorry! You are being rejected because the Passport MRZ is wrong. client_9587
# Sorry! You are being rejected because the Passport MRZ is wrong. client_959
# Sorry! You are being rejected because the phone number is wrong. client_9592
# Sorry! You are being rejected because the passport number is wrong. client_9594
# client_9594 Reject
# Sorry! You are being rejected because the phone number is wrong. client_9595
# Sorry! You are being rejected because the Passport MRZ is wrong. client_9596
# Sorry! You are being rejected because the name is wrong. client_960
# client_960 Reject
# Sorry! You are being rejected because the Passport MRZ is wrong. client_9600
# Sorry! You are being rejected because the Passport MRZ is wrong. client_9602
# Sorry! You are being rejected because the phone number is wrong. client_9603
# Sorry! You are being rejected because the phone number is wrong. client_9625
# Sorry! You are being rejected because the email id is wrong. client_9626
# Sorry! You are being rejected because the passport number is wrong. client_9629
# client_9629 Reject
# Sorry! You are being rejected because the Passport MRZ is wrong. client_965
# Sorry! You are being rejected because the phone number is wrong. client_9651
# Sorry! You are being rejected because the phone number is wrong. client_966
# Sorry! You are being rejected because the name is wrong. client_9661
# client_9661 Reject
# Sorry! You are being rejected because the currency is wrong. client_9662
# Sorry! You are being rejected because the Passport MRZ is wrong. client_9664
# Sorry! You are being rejected because the Passport MRZ is wrong. client_9667
# Sorry! You are being rejected because the phone number is wrong. client_9669
# Sorry! You are being rejected because the phone number is wrong. client_967
# Sorry! You are being rejected because the phone number is wrong. client_9671
# Sorry! You are being rejected because the name is wrong. client_9675
# client_9675 Reject
# Sorry! You are being rejected because the Passport MRZ is wrong. client_9677
# Sorry! You are being rejected because the Passport MRZ is wrong. client_9678
# Sorry! You are being rejected because the postal code is wrong. client_9679
# Sorry! You are being rejected because the Passport MRZ is wrong. client_9681
# Sorry! You are being rejected because the phone number is wrong. client_9683
# Sorry! You are being rejected because the name is wrong. client_9685
# client_9685 Reject
# Sorry! You are being rejected because the Passport MRZ is wrong. client_9686
# Sorry! You are being rejected because the name is wrong. client_9687
# client_9687 Reject
# Sorry! You are being rejected because the Passport MRZ is wrong. client_9689
# Sorry! You are being rejected because the Passport MRZ is wrong. client_9692
# Sorry! You are being rejected because the name is wrong. client_9694
# client_9694 Reject
# Sorry! You are being rejected because the Passport MRZ is wrong. client_9695
# Sorry! You are being rejected because the Passport MRZ is wrong. client_9698
# Sorry! You are being rejected because the passport number is wrong. client_9704
# client_9704 Reject
# Sorry! You are being rejected because the email id is wrong. client_9708
# Sorry! You are being rejected because the passport number is wrong. client_971
# client_971 Reject
# Sorry! You are being rejected because the phone number is wrong. client_9710
# Sorry! You are being rejected because the phone number is wrong. client_9711
# Sorry! You are being rejected because the passport number is wrong. client_972
# client_972 Reject
# Sorry! You are being rejected because the passport number is wrong. client_9724
# client_9724 Reject
# Sorry! You are being rejected because the passport number is wrong. client_9726
# client_9726 Reject
# Sorry! You are being rejected because the Passport MRZ is wrong. client_9728
# Sorry! You are being rejected because the passport number is wrong. client_9733
# client_9733 Reject
# Sorry! You are being rejected because the email id is wrong. client_9737
# Sorry! You are being rejected because the Passport MRZ is wrong. client_9738
# Sorry! You are being rejected because the birthdate is wrong. client_9741
# Sorry! You are being rejected because the name is wrong. client_9744
# client_9744 Reject
# Sorry! You are being rejected because the Passport MRZ is wrong. client_9745
# Sorry! You are being rejected because the name is wrong. client_9746
# client_9746 Reject
# Sorry! You are being rejected because the phone number is wrong. client_9751
# Sorry! You are being rejected because the name is wrong. client_9753
# client_9753 Reject
# Sorry! You are being rejected because the phone number is wrong. client_9757
# Sorry! You are being rejected because the passport number is wrong. client_9758
# client_9758 Reject
# Sorry! You are being rejected because the name is wrong. client_9761
# client_9761 Reject
# Sorry! You are being rejected because the email id is wrong. client_9763
# Sorry! You are being rejected because the Passport MRZ is wrong. client_9775
# Sorry! You are being rejected because the phone number is wrong. client_9776
# Sorry! You are being rejected because the Passport MRZ is wrong. client_9777
# Sorry! You are being rejected because the name is wrong. client_9779
# client_9779 Reject
# Sorry! You are being rejected because the postal code is wrong. client_9781
# Sorry! You are being rejected because the Passport MRZ is wrong. client_9790
# Sorry! You are being rejected because the passport number is wrong. client_9796
# client_9796 Reject
# Sorry! You are being rejected because the phone number is wrong. client_9798
# Invalid postal code for Finland: nan
# client_980 Reject
# Sorry! You are being rejected because the name is wrong. client_9803
# client_9803 Reject
# Sorry! You are being rejected because the name is wrong. client_9805
# client_9805 Reject
# Sorry! You are being rejected because the Passport MRZ is wrong. client_9807
# Sorry! You are being rejected because the name is wrong. client_9809
# client_9809 Reject
# Sorry! You are being rejected because the passport number is wrong. client_9813
# client_9813 Reject
# Sorry! You are being rejected because the Passport MRZ is wrong. client_9814
# Sorry! You are being rejected because the name is wrong. client_9815
# client_9815 Reject
# Sorry! You are being rejected because the passport number is wrong. client_9820
# client_9820 Reject
# Sorry! You are being rejected because the phone number is wrong. client_9821
# Sorry! You are being rejected because the Passport MRZ is wrong. client_9823
# Sorry! You are being rejected because the name is wrong. client_9826
# client_9826 Reject
# Sorry! You are being rejected because the Passport MRZ is wrong. client_9830
# Sorry! You are being rejected because the phone number is wrong. client_9834
# Sorry! You are being rejected because the phone number is wrong. client_9843
# Sorry! You are being rejected because the Passport MRZ is wrong. client_9844
# Sorry! You are being rejected because the Passport MRZ is wrong. client_9845
# Sorry! You are being rejected because the Passport MRZ is wrong. client_9847
# Sorry! You are being rejected because the postal code is wrong. client_9849
# Sorry! You are being rejected because the phone number is wrong. client_985
# Sorry! You are being rejected because the Passport MRZ is wrong. client_9850
# Sorry! You are being rejected because the phone number is wrong. client_9851
# Sorry! You are being rejected because the name is wrong. client_9852
# client_9852 Reject
# Sorry! You are being rejected because the gender is wrong. client_9853
# Sorry! You are being rejected because the passport number is wrong. client_9856
# client_9856 Reject
# Sorry! You are being rejected because the Passport MRZ is wrong. client_986
# Sorry! You are being rejected because the passport number is wrong. client_9863
# client_9863 Reject
# Sorry! You are being rejected because the phone number is wrong. client_9867
# Sorry! You are being rejected because the phone number is wrong. client_9870
# Sorry! You are being rejected because the phone number is wrong. client_9873
# Sorry! You are being rejected because the passport number is wrong. client_9876
# client_9876 Reject
# Sorry! You are being rejected because the Passport MRZ is wrong. client_9877
# Sorry! You are being rejected because the name is wrong. client_9879
# client_9879 Reject
# Sorry! You are being rejected because the Passport MRZ is wrong. client_9880
# Sorry! You are being rejected because the Passport MRZ is wrong. client_9891
# Sorry! You are being rejected because the Passport MRZ is wrong. client_9897
# Sorry! You are being rejected because the name is wrong. client_9899
# client_9899 Reject
# Sorry! You are being rejected because the Passport MRZ is wrong. client_9901
# Sorry! You are being rejected because the passport dates are wrong. client_9902
# Sorry! You are being rejected because the Passport MRZ is wrong. client_9904
# Sorry! You are being rejected because the phone number is wrong. client_9906
# Sorry! You are being rejected because the Passport MRZ is wrong. client_9907
# Sorry! You are being rejected because the name is wrong. client_9915
# client_9915 Reject
# Sorry! You are being rejected because the passport number is wrong. client_9916
# client_9916 Reject
# Sorry! You are being rejected because the email id is wrong. client_992
# Sorry! You are being rejected because the currency is wrong. client_9923
# Sorry! You are being rejected because the Passport MRZ is wrong. client_9928
# Sorry! You are being rejected because the passport number is wrong. client_9929
# client_9929 Reject
# Sorry! You are being rejected because the phone number is wrong. client_9930
# Sorry! You are being rejected because the passport number is wrong. client_9933
# client_9933 Reject
# Sorry! You are being rejected because the birthdate is wrong. client_9934
# Sorry! You are being rejected because the postal code is wrong. client_9935
# Sorry! You are being rejected because the phone number is wrong. client_9937
# Sorry! You are being rejected because the Passport MRZ is wrong. client_9950
# Sorry! You are being rejected because the Passport MRZ is wrong. client_9956
# Sorry! You are being rejected because the postal code is wrong. client_9963
# Sorry! You are being rejected because the phone number is wrong. client_9968
# Sorry! You are being rejected because the passport number is wrong. client_997
# client_997 Reject
# Sorry! You are being rejected because the passport number is wrong. client_9970
# client_9970 Reject
# Sorry! You are being rejected because the phone number is wrong. client_9971
# Sorry! You are being rejected because the birthdate is wrong. client_9978
# Sorry! You are being rejected because the phone number is wrong. client_998
# Sorry! You are being rejected because the Passport MRZ is wrong. client_9980
# Sorry! You are being rejected because the Passport MRZ is wrong. client_9981
# Sorry! You are being rejected because the phone number is wrong. client_9983
# Sorry! You are being rejected because the phone number is wrong. client_999
# Sorry! You are being rejected because the phone number is wrong. client_9997
# 2874

# %% [markdown]
# ### Training MLP

# %%
currency_rate = {"CHF": 1, "EUR": 0.95738, "DKK":0.128}
investment_experience = {'Experienced':0, 'Expert':1, 'Inexperienced':2}
type_of_mandate = {'Discretionary':0, 'Advisory':1, 'Hybrid':2, 'Execution-Only':3}
preferred_markets = {'Germany':0, 'Austria':1, 'France':2, 'Finland':3, 'Italy':4, 'Belgium':5, 'Spain':6, 'Switzerland':7, 'Netherlands':8, 'Denmark':9}
investment_risk_profile = {'Low':0, 'Considerable':1, 'Aggressive':2, 'Conservative':3, 'Moderate':4, 'High':5, 'Balanced':6}
cuurency_list = ["CHF", "EUR", "DKK"]

# %%
client_profile_filtered = client_profile_pd[~client_profile_pd["index"].isin(reje_ids)]
passport_filtered = passport_pd[~passport_pd["index"].isin(reje_ids)]
account_form_filtered = account_form_pd[~account_form_pd["index"].isin(reje_ids)]

print(len(client_profile_filtered))
# Out:
# 7125

# %%
def calculate_property(data, currency_rate):
    money_data = []
    currency = data["currency"]
    
    rate = currency_rate[currency]

    savings = data["aum.savings"] * rate
    inheritance = data["aum.inheritance"] * rate
    real_estate_value = data["aum.real_estate_value"] * rate

    total_money = savings + inheritance + real_estate_value
    return [savings,inheritance,real_estate_value,total_money]

def get_investment_info(data):
    raw_experience = data.get("investment_experience")
    raw_markets = ast.literal_eval(data.get("preferred_markets", []))
    raw_mandate = data.get("type_of_mandate")
    raw_profile = data.get("investment_risk_profile")

    experience = investment_experience[raw_experience] if pd.notnull(raw_experience) else None
    markets = preferred_markets[raw_markets[0]] if pd.notnull(raw_markets[0]) else None
    mandate = type_of_mandate[raw_mandate] if pd.notnull(raw_mandate) else None
    profile = investment_risk_profile[raw_profile] if pd.notnull(raw_profile) else None

    if experience == None or markets==None or mandate==None or profile==None:
        return None
    return [experience,markets,mandate,profile]

# %%
money_list = []
label_list = []
for index in client_profile_filtered.index:
    data = client_profile_filtered.loc[index]
    currency = data["currency"]
    if currency not in cuurency_list:
       continue 
    money_per = calculate_property(data,currency_rate)
    investment_per = get_investment_info(data)
    if investment_per == None:
        continue
    label_per = data["label"]
    money_per = money_per + investment_per
    money_per.append(label_per)
    money_list.append(money_per)

# %%
print(len(money_list))
# Out:
# 7073

# %%
df = pd.DataFrame(money_list, columns=['saving', 'inheritance', 'real_estate_value', 'total','investment_experience','preferred_markets','type_of_mandate','investment_risk_profile', 'label'])

# %%
class SimpleModel(nn.Module):
    def __init__(self, input_dim, num_classes, dropout_rate=0.2):
        super(SimpleModel, self).__init__()
        self.fc1 = nn.Linear(input_dim, 128)
        self.relu = nn.ReLU()
        self.fc2 = nn.Linear(128, 64)
        self.fc3 = nn.Linear(64, 16)
        self.fc4 = nn.Linear(16, num_classes)

        self.dropout = nn.Dropout(p=dropout_rate)
    
    def forward(self, x):
        x = self.relu(self.fc1(x))
        x = self.dropout(x)
        x = self.relu(self.fc2(x))
        x = self.dropout(x)
        x = self.relu(self.fc3(x))
        x = self.fc4(x)
        return x

# %%
# 'investment_experience','preferred_markets','type_of_mandate','investment_risk_profile'
df_subset = df[['saving', 'real_estate_value','total','investment_experience','investment_risk_profile','type_of_mandate','label']]

# %%
X = df_subset.drop('label', axis=1)  # 特征数据
y = df_subset['label'] 

X_encoded = pd.get_dummies(X, columns=['investment_experience','investment_risk_profile','type_of_mandate'])
# print(X_encoded)

le = LabelEncoder()
y_encoded = le.fit_transform(y)

X_train, X_test, y_train, y_test = train_test_split(
    X_encoded , y_encoded, test_size=0.2, random_state=42
)

# %%
X_train_tensor = torch.tensor(X_train.values, dtype=torch.float32)
y_train_tensor = torch.tensor(y_train, dtype=torch.long)
X_test_tensor = torch.tensor(X_test.values, dtype=torch.float32)
y_test_tensor = torch.tensor(y_test, dtype=torch.long)

# 6. 构建 TensorDataset 和 DataLoader
train_dataset = TensorDataset(X_train_tensor, y_train_tensor)
test_dataset = TensorDataset(X_test_tensor, y_test_tensor)

batch_size = 32
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %%
input_dim = X_train_tensor.shape[1]
num_classes = len(torch.unique(y_train_tensor))  # 或者使用 len(le.classes_) 如果用 LabelEncoder
print(input_dim)
print(num_classes)
model = SimpleModel(input_dim, num_classes)

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001, weight_decay=1e-5)
scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.5)
# Out:
# 17
# 2

# %%
num_epochs = 100
for epoch in range(num_epochs):
    model.train()  
    running_loss = 0.0
    for batch_inputs, batch_labels in train_loader:
        optimizer.zero_grad()            
        outputs = model(batch_inputs)      
        loss = criterion(outputs, batch_labels)  
        loss.backward()                    
        optimizer.step()                   
        
        running_loss += loss.item()
        
    scheduler.step()
    current_lr = optimizer.param_groups[0]['lr']
    avg_loss = running_loss / len(train_loader)
    print(f"Epoch {epoch+1}/{num_epochs}, Loss: {avg_loss:.4f}")
# Out:
# Epoch 1/100, Loss: 1812.9545
# Epoch 2/100, Loss: 24.6150
# Epoch 3/100, Loss: 11.9016
# Epoch 4/100, Loss: 8.1852
# Epoch 5/100, Loss: 3.0119
# Epoch 6/100, Loss: 2.2361
# Epoch 7/100, Loss: 2.6652
# Epoch 8/100, Loss: 2.2898
# Epoch 9/100, Loss: 1.1767
# Epoch 10/100, Loss: 1.5017
# Epoch 11/100, Loss: 0.7462
# Epoch 12/100, Loss: 0.7944
# Epoch 13/100, Loss: 0.7038
# Epoch 14/100, Loss: 0.7194
# Epoch 15/100, Loss: 0.7931
# Epoch 16/100, Loss: 0.7888
# Epoch 17/100, Loss: 0.8073
# Epoch 18/100, Loss: 0.6467
# Epoch 19/100, Loss: 0.6153
# Epoch 20/100, Loss: 0.8011
# Epoch 21/100, Loss: 0.6202
# Epoch 22/100, Loss: 0.6166
# Epoch 23/100, Loss: 0.9061
# Epoch 24/100, Loss: 0.6681
# Epoch 25/100, Loss: 1.1517
# Epoch 26/100, Loss: 0.9386
# Epoch 27/100, Loss: 0.6521
# Epoch 28/100, Loss: 0.7234
# Epoch 29/100, Loss: 0.6072
# Epoch 30/100, Loss: 0.6397
# Epoch 31/100, Loss: 0.6166
# Epoch 32/100, Loss: 0.6075
# Epoch 33/100, Loss: 1.5269
# Epoch 34/100, Loss: 0.6218
# Epoch 35/100, Loss: 0.6141
# Epoch 36/100, Loss: 0.6941
# Epoch 37/100, Loss: 0.6892
# Epoch 38/100, Loss: 0.7604
# Epoch 39/100, Loss: 0.7756
# Epoch 40/100, Loss: 0.6095
# Epoch 41/100, Loss: 0.8118
# Epoch 42/100, Loss: 0.6199
# Epoch 43/100, Loss: 0.8379
# Epoch 44/100, Loss: 0.6085
# Epoch 45/100, Loss: 0.7199
# Epoch 46/100, Loss: 0.6073
# Epoch 47/100, Loss: 0.6207
# Epoch 48/100, Loss: 0.6057
# Epoch 49/100, Loss: 0.6065
# Epoch 50/100, Loss: 0.6148
# Epoch 51/100, Loss: 0.6204
# Epoch 52/100, Loss: 0.6504
# Epoch 53/100, Loss: 0.6056
# Epoch 54/100, Loss: 0.6724
# Epoch 55/100, Loss: 0.6295
# Epoch 56/100, Loss: 0.6053
# Epoch 57/100, Loss: 0.6803
# Epoch 58/100, Loss: 0.6062
# Epoch 59/100, Loss: 0.6066
# Epoch 60/100, Loss: 0.6204
# Epoch 61/100, Loss: 0.6086
# Epoch 62/100, Loss: 0.6056
# Epoch 63/100, Loss: 0.6055
# Epoch 64/100, Loss: 0.6057
# Epoch 65/100, Loss: 0.6057
# Epoch 66/100, Loss: 0.6058
# Epoch 67/100, Loss: 0.6060
# Epoch 68/100, Loss: 0.6061
# Epoch 69/100, Loss: 0.6198
# Epoch 70/100, Loss: 0.6081
# Epoch 71/100, Loss: 0.6181
# Epoch 72/100, Loss: 0.6054
# Epoch 73/100, Loss: 0.6111
# Epoch 74/100, Loss: 0.6070
# Epoch 75/100, Loss: 0.6080
# Epoch 76/100, Loss: 0.6086
# Epoch 77/100, Loss: 0.6077
# Epoch 78/100, Loss: 0.6056
# Epoch 79/100, Loss: 0.7643
# Epoch 80/100, Loss: 0.6071
# Epoch 81/100, Loss: 0.6752
# Epoch 82/100, Loss: 0.6439
# Epoch 83/100, Loss: 0.6056
# Epoch 84/100, Loss: 0.6134
# Epoch 85/100, Loss: 0.6066
# Epoch 86/100, Loss: 0.6058
# Epoch 87/100, Loss: 0.6056
# Epoch 88/100, Loss: 0.6068
# Epoch 89/100, Loss: 0.6057
# Epoch 90/100, Loss: 0.6073
# Epoch 91/100, Loss: 0.6058
# Epoch 92/100, Loss: 0.6572
# Epoch 93/100, Loss: 0.6076
# Epoch 94/100, Loss: 0.6060
# Epoch 95/100, Loss: 0.9109
# Epoch 96/100, Loss: 0.6228
# Epoch 97/100, Loss: 0.6121
# Epoch 98/100, Loss: 0.6056
# Epoch 99/100, Loss: 0.6390
# Epoch 100/100, Loss: 0.6673

# %%
correct = 0
total = 0
model.eval()  # 切换到评估模式

with torch.no_grad():
    for batch_inputs, batch_labels in test_loader:
        outputs = model(batch_inputs)  # 输出形状 (batch_size, 2)
        predicted = torch.argmax(outputs, dim=1)
        total += batch_labels.size(0)
        correct += (predicted == batch_labels).sum().item()

accuracy = correct / total
print(f"Test Accuracy: {accuracy:.4f}")
# Test Accuracy: 0.7132
# Out:
# Test Accuracy: 0.7166

# %% [markdown]
# ### Validation

# %% [markdown]
# #### Data unzipping and preprocessing

# %%
# Code to load zip files and extract them
import zipfile
import os
from tqdm import tqdm
import sys
import pandas as pd
import json

# DIRECTORY WHERE THE DATA IS STORED, IF CURRENT DIR, USE "./"
directory = "./datathon2025"

def extract_zip(zip_path, extract_to,log=False):
    """Extracts the contents of a zip file to a specified directory."""
    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
        zip_ref.extractall(extract_to)
    if log:
        print(f"Extracted {zip_path} to {extract_to}")
# Get zip files in the directory

if not os.path.exists(directory):
    print(f"Directory {directory} does not exist.")
    sys.exit(1)


zip_files = [f for f in os.listdir(directory) if f.endswith('.zip')]
zip_files = [os.path.join(directory, f) for f in zip_files]

if not zip_files:
    print("No zip files found in the current directory.")

else:
    # Create a directory to extract files
    extract_dir = os.path.join(directory, "extracted_files")
    if not os.path.exists(extract_dir):
        os.makedirs(extract_dir)

    # Extract each zip file
    for zip_file in zip_files:
        extract_zip(zip_file, extract_dir,log=True)

    print(f"All zip files have been extracted to {extract_dir}.")

# Extract all zip files in extracted_files

extracted_files = os.listdir(extract_dir)
for file in tqdm(extracted_files):
    if file.endswith('.zip'):
        file_path = os.path.join(extract_dir, file)
        # Create a subdirectory for each zip file
        sub_dir = os.path.join(extract_dir, os.path.splitext(file)[0])
        if not os.path.exists(sub_dir):
            os.makedirs(sub_dir)
        extract_zip(file_path, sub_dir,log=False)
        os.remove(file_path)

        
print("All zip files in extracted_files have been extracted and removed.")
# Out:
# Extracted ./datathon2025\datathon_part1.zip to ./datathon2025\extracted_files
# Extracted ./datathon2025\datathon_part2.zip to ./datathon2025\extracted_files
# Extracted ./datathon2025\datathon_part3.zip to ./datathon2025\extracted_files
# Extracted ./datathon2025\datathon_part4.zip to ./datathon2025\extracted_files
# All zip files have been extracted to ./datathon2025\extracted_files.
# 100%|██████████| 10000/10000 [02:53<00:00, 57.68it/s]
# All zip files in extracted_files have been extracted and removed.

# %%
# Code to load the files, process them and store as csv

# Extract_dir contains all the extracted files in separate folders per client
extract_dir = os.path.join(directory, "extracted_files")

# Get all the folders in the extracted_files directory
folders = [f for f in os.listdir(extract_dir) if os.path.isdir(os.path.join(extract_dir, f))]

# Create a dict for passport data
passport_data_dict = {}

# Create a dict for account form data
account_form_data_dict = {}

# Create a dict for client profile data
client_profile_data_dict = {}

# Create a dict for labels
label_dict = {}

# Create a dict for client description
client_description_dict = {}

print(extract_dir)


# Read all the files in the folders
for client_id in tqdm(folders):

    client_dir = os.path.join(extract_dir, client_id)

    passport_data_file = os.path.join(client_dir, 'passport.json')
    account_form_data_file = os.path.join(client_dir, 'account_form.json')
    client_profile_data_file = os.path.join(client_dir, 'client_profile.json')
    client_description_file = os.path.join(client_dir, 'client_description.json')
    label_dict_file = os.path.join(client_dir, 'label.json')

    # Passport data load
    if os.path.exists(passport_data_file):
        with open(passport_data_file, 'r') as f:
            passport_data = json.load(f)
            passport_data_dict[client_id] = passport_data
    else:
        print(f"Passport data file not found for client {client_id}")
    # Account form data load
    if os.path.exists(account_form_data_file):
        with open(account_form_data_file, 'r') as f:
            account_form_data = json.load(f)
            account_form_data_dict[client_id] = account_form_data
    else:
        print(f"Account form data file not found for client {client_id}")
    # Client profile data load
    if os.path.exists(client_profile_data_file):
        with open(client_profile_data_file, 'r') as f:
            client_profile_data = json.load(f)
            client_profile_data_dict[client_id] = client_profile_data
    else:
        print(f"Client profile data file not found for client {client_id}")

    # Client description data load

    if os.path.exists(client_description_file):
        with open(client_description_file, 'r') as f:
            client_description = json.load(f)
            client_description_dict[client_id] = client_description
    else:
        print(f"Client description data file not found for client {client_id}")

    # Label data load
    if os.path.exists(label_dict_file):
        with open(label_dict_file, 'r') as f:
            label_data = json.load(f)
            label_dict[client_id] = label_data["label"]
    else:
        print(f"Label data file not found for client {client_id}")

    


# Convert the dicts to dataframes with dictionary key as a column called client_id
passport_data_df = pd.DataFrame.from_dict(passport_data_dict, orient='index').reset_index()
account_form_data_df = pd.DataFrame.from_dict(account_form_data_dict, orient='index').reset_index()
client_profile_data_df = pd.DataFrame.from_dict(client_profile_data_dict, orient='index').reset_index()
client_description_df = pd.DataFrame.from_dict(client_description_dict, orient='index').reset_index()

# Flatten the dataframe columns which have nested json objects
passport_data_df = pd.json_normalize(passport_data_df.to_dict(orient='records'))
account_form_data_df = pd.json_normalize(account_form_data_df.to_dict(orient='records'))
client_profile_data_df = pd.json_normalize(client_profile_data_df.to_dict(orient='records'))
client_description_df = pd.json_normalize(client_description_df.to_dict(orient='records'))

# Add labels to the dataframes based on mapping label with client_id
passport_data_df['label'] = passport_data_df['index'].map(label_dict)
account_form_data_df['label'] = account_form_data_df['index'].map(label_dict)
client_profile_data_df['label'] = client_profile_data_df['index'].map(label_dict)
client_description_df['label'] = client_description_df['index'].map(label_dict)


# Save the dataframes to csv files
passport_data_df.to_csv('passport_data_with_label.csv', index=False)
account_form_data_df.to_csv('account_form_data_with_label.csv', index=False)
client_profile_data_df.to_csv('client_profile_data_with_label.csv', index=False)
client_description_df.to_csv('client_description_with_label.csv', index=False)

# Clean the account_form_data removing passport_number in list form
account_form_data_df['passport_number'] = account_form_data_df['passport_number'].apply(lambda x: x[0] if isinstance(x, list) else x)

# Replace columns with spaces with underscores
account_form_data_df.columns = account_form_data_df.columns.str.replace(' ', '_')

# Save cleaned csv file
account_form_data_df.to_csv('account_form_data_with_label_cleaned.csv', index=False)
# Out:
# ./datathon2025\extracted_files
# 100%|██████████| 10000/10000 [06:13<00:00, 26.77it/s]

# %% [markdown]
# #### Load data

# %%
passport_pd = pd.read_csv('./passport_data_with_label.csv')

passport_pd.head(5)

# %%
account_form_pd = pd.read_csv('./account_form_data_with_label_cleaned.csv')

account_form_pd.head(20)

# %%
description_pd = pd.read_csv('./client_profile_data_with_label.csv')
description_pd.head(5)

# %%
client_profile_pd = pd.read_csv('./client_profile_data_with_label.csv')
client_profile_pd.head(5)

# %% [markdown]
# #### Validation

# %%
reje_ids,labels = validate_data(passport_pd, account_form_pd, client_profile_pd,LLM_Model)

len(reje_ids)

# %%
# Fil
client_profile_filtered = client_profile_pd[~client_profile_pd["index"].isin(reje_ids)]
passport_filtered = passport_pd[~passport_pd["index"].isin(reje_ids)]
account_form_filtered = account_form_pd[~account_form_pd["index"].isin(reje_ids)]

print(len(client_profile_filtered))

# %%
money_list = []
for index in client_profile_filtered.index:
    data = client_profile_filtered.loc[index]
    currency = data["currency"]
    if currency not in cuurency_list:
       continue 
    money_per = calculate_property(data,currency_rate)
    investment_per = get_investment_info(data)
    if investment_per == None:
        continue
    money_per = [index] +money_per + investment_per
    money_list.append(money_per)

# %%
df = pd.DataFrame(money_list, columns=['index', 'saving', 'inheritance', 'real_estate_value', 'total','investment_experience','preferred_markets','type_of_mandate','investment_risk_profile', 'label'])
df_subset = df[['saving', 'real_estate_value','total','investment_experience','investment_risk_profile','type_of_mandate','label']]
df_index = df[['index']]

# %%
X = df_subset.drop('label', axis=1)  # 特征数据
y = df_subset['label'] 

X_encoded = pd.get_dummies(X, columns=['investment_experience','investment_risk_profile','type_of_mandate'])

le = LabelEncoder()
y_encoded = le.fit_transform(y)

X_test_tensor = torch.tensor(c.values, dtype=torch.float32)
y_test_tensor = torch.tensor(y_encoded, dtype=torch.long)

test_dataset = TensorDataset(X_test_tensor, y_test_tensor)

batch_size = 32
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %%
# ML?
correct = 0
total = 0
model.eval()  # 切换到评估模式
result = []

with torch.no_grad():
    for batch_inputs, batch_labels in test_loader:
        outputs = model(batch_inputs)  # 输出形状 (batch_size, 2)
        predicted = torch.argmax(outputs, dim=1)
        result.append(predicted)
        total += batch_labels.size(0)
        correct += (predicted == batch_labels).sum().item()

accuracy = correct / total
print(f"Test Accuracy: {accuracy:.4f}")

df_index = df[['index']]
reje_ids
# Test Accuracy: 0.7132
